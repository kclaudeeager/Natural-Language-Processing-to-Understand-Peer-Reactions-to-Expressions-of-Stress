# %%
data_list=list(dict())
all_users=[dict()]
media={}
def getAllTweetsData(response):
    # process users
    global data_list
    global all_users
    users = {}
    tweet_user=[]
   
    all_tweet_list=list()
# tweet specific info
    response.includes.setdefault('media',None)
    for user in response.includes['users']:
    # print(user.username)
    # print(user.name)
        users[user.id] = f"{user.name} (@{user.username}) [{user.profile_image_url}]"
        print(users[user.id])
        #print("User:>>>>>>",{user})
        #all_users.append({user})
    # print(dir(inclu))
 
# process media attachment

    global media
    if response.includes['media'] is not None:
        for item in response.includes['media']:
            media[item.media_key] = f"{item.url} - {item.height}x{item.width} - Alt: {item.alt_text}"
            print(media[item.media_key])
 
 
    tweets = response.data
 
# The expanded tweet offers a lot more data
    for tweet in tweets:
        print("type of the tweet:>>>>",type(tweet))
        data_list.append(dict(tweet))
        print('-' * 50)
        print(f"{tweet.id} ({tweet.created_at}) - {users[tweet.author_id]}:\n {tweet.text} \n")
        metric = tweet.public_metrics
        print(f"retweets: {metric['retweet_count']} | likes: {metric['like_count']}")
        if tweet.attachments is not None:
            for media_key in tweet.attachments['media_keys']:
                print(f"Media attachment: {media[media_key]}")

# %%
# !pip install tweepy

# %%
import tweepy
import requests

# your bearer token
MY_BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D"
# create your client 
client = tweepy.Client(bearer_token=MY_BEARER_TOKEN)
# query to search for tweets
query = "#stressed lang:en -is:retweet"
next_token={}
conversationIds=list()
tweet_ids=list()
# your start and end time for fetching tweets
start_time = "2022-06-16T00:00:00Z"
end_time = "2022-06-22T00:00:00Z"
user_list=[]
#MY_BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D"
# create your client 
client = tweepy.Client(bearer_token=MY_BEARER_TOKEN)


next_token={}
tweet_fields = ["created_at", "text", "source","id",'attachments',"author_id","in_reply_to_user_id","geo","conversation_id","lang","public_metrics","referenced_tweets","reply_settings","source"]
res = []
for i in tweet_fields:
    if i not in res:
        res.append(i)
def run_response():
    global next_token
    response = client.search_recent_tweets(
                "#stressed lang:en -is:retweet", 
                start_time=start_time,
                end_time=end_time,
                max_results=100,
                expansions="author_id,attachments.media_keys,in_reply_to_user_id,geo.place_id",
                tweet_fields=res,
                user_fields="created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld",
                next_token=next_token,
                media_fields="public_metrics,url,height,width,alt_text")
    response.meta.setdefault('next_token',None)
    if response.meta is not None:
        next_token={response.meta['next_token']}
    getAllTweetsData(response)
    #print('Next token :',next_token)
    i=0
    for tweet in response.data:
    
   
    # user information for the first tweet
        tweet_user=response.includes["users"][i]
        all_users.append(dict(tweet_user))
        #print(dict(tweet_user)," <<<User\n ____________________________________________________________________________\n\n")
        #print(dict(tweet),"\n\n")
        dict_tweet = dict(tweet)
        print(dict_tweet.keys())
        print('---------------------------------')
        data_list.append(dict(tweet))
        ++i
        tweetId=tweet.id
        tweet_ids.append(tweetId)
        q=tweet.conversation_id
        conversationIds.append(q)


for i in range(0,100):
    run_response()

# %%
import requests
import time
def fetchReplies(tweetId):
      
  time.sleep(1) 
  payload = ""
  headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D',
    'Cookie': 'guest_id=v1%3A165461133818653501; guest_id_ads=v1%3A165461133818653501; guest_id_marketing=v1%3A165461133818653501; personalization_id="v1_2aA81CEcKTHAJ4Cp/ipjcg=="'
  }
  url = "https://api.twitter.com/2/tweets/search/recent?query=conversation_id:"+str(tweetId)
  response = requests.request("GET", url, headers=headers, data=payload)
  return response.text

# %%
import time
class TimerClass:
# Timer starts

    starttime = time.time()
    lasttime = starttime
    lapnum = 1
    value = ""
    
    print("Press ENTER for each lap.\nType Q and press ENTER to stop.")

    def getUsedTime(self):
        valueDict=dict()
        # global value,starttime,lasttime,lapnum
        m=s=h=0.00
        while self.value.lower() != "q":
                    
            # Input for the ENTER key press
            self.value = input()
        
            # The current lap-time
            self.laptime = round((time.time() - self.lasttime), 2)
        
            # Total time elapsed since the timer started
            self.totaltime = round((time.time() - self.starttime), 2)
            m, s = divmod(self.laptime, 60)
            h, m = divmod(m, 60)
            # Printing the lap number, lap-time, and total time
            #print(f'{h:d}:{m:02d}:{s:02d}')
            print("Lap No. "+str(self.lapnum))
            print("Total Time: "+str(self.totaltime))
            # print("Lap Time: "+str(laptime))
            print(m)
            print('{:f}:{:02f}:{:02f}'.format(h, m, s))
                    
            print("*"*20)
        
            # Updating the previous total time and lap number
            lasttime = time.time()
            self.lapnum += 1
            valueDict={"hr":h,"min":m,"sec":s,"total":self.totaltime,"times":self.lapnum}
        return valueDict

# %%
# create a list of records
tweet_info_ls = []
new_user_list=list(dict())
newDataList=[{}]
#print(len(all_users))
#print('all users: ',all_users)

for user_data in all_users:
    #print(user_data,'\n__________________________________________________________________________________________________________________________________________________________________________________________________________________________\n')
    if user_data=={}:
        all_users.remove(user_data)
#print("user size",len(all_users))
#Remove duplicates
for user in all_users:
    if user not in new_user_list:
        new_user_list.append(user)
for tweetData in data_list:
    if tweetData not in newDataList:
        newDataList.append(tweetData)

# %%
# import the pandas library
import time
import pandas as pd
from time import sleep

#print("data size : ",len(data_list))
# iterate over each tweet and corresponding user details
k=0
startTime=time.time()
totalUsers=len(all_users)
print(totalUsers)
print(startTime)
for tweet, user in zip(data_list, all_users):
    difference=0
    #print(user)
    print("k is ",k)
    print('...................................................................')
    user.setdefault('location', "")
    attachments=[]
    #print(media)
    tweet.setdefault('attachments',None)
    found_attachment=tweet['attachments']
    print(tweet)
    if found_attachment is not None:
        #print(found_attachment,'\n___________________________________________________________________')

        
        for media_key in found_attachment['media_keys']:
            attachment= media[media_key]
            print(attachment)
            attachments.append(attachment)
    #print(attachments)  
    metric=tweet['public_metrics']
    replies=fetchReplies(tweet['id'])
    tweet_info = {
        'created_at': tweet['created_at'],
        'id':tweet['id'],
        'text': tweet['text'],
        'source': tweet['source'],
        'name': user['name'],
        'username': user['username'],
        'location': user['location'],
        'verified': user['verified'],
        'description': user['description'],
        'profile_image_url':user['profile_image_url'],
        'retweets':metric['retweet_count'],
        'likes':metric['like_count'],
        'attachments':attachments,
        'replies':replies
          
    }
    print(tweet_info)
    tweet_info_ls.append(tweet_info)
    if k==850:
        print("Now k is:>>>>>>>>>>>>>>>>",k)
        difference=round(time.time()-startTime,2)
        m, s = divmod(difference, 60)            
        h, m = divmod(m, 60)
        if m<15:
            k=0
            sleep((15-m)*60)
            
            startTime=time.time()
    k=k+1

# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
display(tweets_df)
#print(midea['1535705930641207296'])

# %%
import csv


#tweets_df.to_csv(r'newRetrievedData.csv',index = False, header=True)
tweets_df.to_csv(r'The_22_06_RetrievedData.csv',index = False, header=True)

# newRetrievedData_cleared_df =pd.read_csv('newRetrievedData.csv')
newRetrievedData_cleared_df =pd.read_csv('The_22_06_RetrievedData.csv')
replies = newRetrievedData_cleared_df["replies"] 

#print(replies)
#display(replies)
#print(len(tweets_df["replies"].value_counts()))

# %%
print(len(replies.value_counts()))

# %%
import csv


tweets_df.to_csv(r'twitterDataWithReplies.csv',index = False, header=True)

cleared_df =pd.read_csv('twitterDataWithReplies.csv')
replies = cleared_df["replies"] 

print(len(cleared_df["replies"].value_counts()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 import csv
# ----> 4 tweets_df.to_csv(r'twitterDataWithReplies.csv',index = False, header=True)
#       6 cleared_df =pd.read_csv('twitterDataWithReplies.csv')
#       7 replies = cleared_df["replies"]
#
# NameError: name 'tweets_df' is not defined

# %%
def removeUnWantedData(tweet_data,clean_replies_csv_file):
        # display(tweet_data)
    cleaned_tweet_data = tweet_data.drop_duplicates()
    # print(len(cleaned_tweet_data))
    # display(cleaned_tweet_data)
    no_reply = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}'])]
    # display(no_reply)
    # {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
    unprocesed = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])]
    # display(unprocesed["id"])
    no_reply_and_unp = cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}', '{"meta":{"result_count":0}}'])
    # print(f"total doc : {len(cleaned_tweet_data)}, with no reply : {len(no_reply)} , unprocessed : {len(unprocesed)} ")
    # print("with replay : ",len(cleaned_tweet_data) -(len(no_reply) + len(unprocesed)))

    clean_replies = ~ cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}','{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])
    clean_replies_df = cleaned_tweet_data[clean_replies]
    display(clean_replies_df)
    clean_replies_df.to_csv(r''+clean_replies_csv_file+'',index = False, header=True)
    return unprocesed,clean_replies_csv_file

# %%
# remove duplicates
import csv
import pandas as pd


# tweets_df.to_csv(r'twitterData.csv',index = False, header=True)
tweet_data = pd.read_csv("The_22_06_RetrievedData.csv")
print(len(tweet_data))
# # display(tweet_data)
cleaned_tweet_data = tweet_data.drop_duplicates()
# # print(len(cleaned_tweet_data))
# # display(cleaned_tweet_data)
# no_reply = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}'])]
# # display(no_reply)
# # {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# unprocesed = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])]
# # display(unprocesed["id"])
# no_reply_and_unp = cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}', '{"meta":{"result_count":0}}'])
# # print(f"total doc : {len(cleaned_tweet_data)}, with no reply : {len(no_reply)} , unprocessed : {len(unprocesed)} ")
# # print("with replay : ",len(cleaned_tweet_data) -(len(no_reply) + len(unprocesed)))

# clean_replies = ~ cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}','{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])
# clean_replies_df = cleaned_tweet_data[clean_replies]
# display(clean_replies_df)
print(len(cleaned_tweet_data))
unprocesed,clean_replies_from_first_cleared_22_06_data=removeUnWantedData(cleaned_tweet_data,"clean_replies_from_first_cleared_22_06_data.csv")
print(len(unprocesed))
# Out:
# 8284
# 990
#                     created_at                   id  \
# 20   2022-06-21 17:35:06+00:00  1539300891643232258
# 25   2022-06-21 15:20:41+00:00  1539267065550454785
# 47   2022-06-21 05:43:17+00:00  1539121758392963073
# 52   2022-06-21 02:10:05+00:00  1539068103891509248
# 55   2022-06-20 22:32:25+00:00  1539013329041215490
# 56   2022-06-20 20:45:07+00:00  1538986326955106304
# 58   2022-06-20 20:10:29+00:00  1538977608037109760
# 59   2022-06-20 19:43:40+00:00  1538970861285298177
# 62   2022-06-20 17:27:40+00:00  1538936636003655682
# 86   2022-06-19 23:52:00+00:00  1538670967748235264
# 99   2022-06-19 14:22:27+00:00  1538527634686103555
# 120  2022-06-21 17:35:06+00:00  1539300891643232258
# 125  2022-06-21 15:20:41+00:00  1539267065550454785
# 147  2022-06-21 05:43:17+00:00  1539121758392963073
# 152  2022-06-21 02:10:05+00:00  1539068103891509248
# 155  2022-06-20 22:32:25+00:00  1539013329041215490
# 156  2022-06-20 20:45:07+00:00  1538986326955106304
# ...

# %%
#clean_replies_df.to_csv(r'clean_replies_from_first_cleared_22_06_data.csv',index = False, header=True)

# %%
import time
import pandas as pd
from time import sleep
def proccessUnproccessed(unprocesed):
    #global tweet_data
        # unprocessed df to list 
    unprocesed_list = []
    print(unprocesed.columns)
    for index, tweet in unprocesed.iterrows():
        new_unp =  {
            'created_at': tweet['created_at'],
            'id':tweet['id'],
            'text': tweet['text'],
            'source': tweet['source'],
            'name': tweet['name'],
            'username': tweet['username'],
            'location': tweet['location'],
            'verified': tweet['verified'],
            'description': tweet['description'],
            'profile_image_url':tweet['profile_image_url'],
            'retweets':tweet['retweets'],
            'likes':tweet['likes'],
            'attachments':tweet['attachments'],
            'replies':tweet['replies']
        }
        unprocesed_list.append(new_unp)
    #display(unprocesed_list)
    replies_list=[]
    for tweetData in unprocesed_list:
        reply=fetchReplies(tweetData['id'])
        replies_list.append(reply)
        #print(reply)
#         if reply=='{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}':
#             break
#         if '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}' in reply:
#             break
        tweetData['replies']=reply
        print(tweetData)
        
    proccessed=unprocesed_list
    return proccessed

# %%
print(len(unprocesed))
display(unprocesed)
# Out:
# 495
#                      created_at                   id  \
# 350   2022-06-18 05:10:02+00:00  1538026227767791617
# 351   2022-06-18 02:31:03+00:00  1537986217295216641
# 352   2022-06-18 01:40:15+00:00  1537973434218467330
# 353   2022-06-17 23:38:55+00:00  1537942900465467394
# 354   2022-06-17 23:36:45+00:00  1537942353230475264
# ...                         ...                  ...
# 1832  2022-06-18 11:55:34+00:00  1538128284353024003
# 1833  2022-06-18 07:10:28+00:00  1538056534319677442
# 1834  2022-06-18 07:01:48+00:00  1538054353692639236
# 1836  2022-06-18 07:01:46+00:00  1538054347380203523
# 1837  2022-06-18 07:01:45+00:00  1538054343387226113
#
#                                                    text              source  \
# 350   my bestie got this for me lol I need it today ...  Twitter for iPhone
# 351         Finally watching  #Ozark  finale. #stressed  Twitter for iPhone
# 352   Is it bad I wanna start doing stuff Inee never...  Twitter for iPhone
# ...

# %%
#display(unprocesed_list)
import time
import pandas as pd
from time import sleep
tweetData=proccessUnproccessed(unprocesed)
display(tweetData)
dataFrame=pd.DataFrame(tweetData)
display(dataFrame)
# new_no_replies = dataFrame[dataFrame['replies'].isin(['{"meta":{"result_count":0}}'])]
# with_replies = ~ dataFrame['replies'].isin(['{"meta":{"result_count":0}}'])
# pure_replies = ~ dataFrame['replies'].isin(['{"meta":{"result_count":0}}', '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])
# from_many_replies_reretrived = dataFrame[pure_replies]
#dataFrame=removeUnWantedData(dataFrame)
#display(dataFrame)
# Out:
# Index(['created_at', 'id', 'text', 'source', 'name', 'username', 'location',
#        'verified', 'description', 'profile_image_url', 'retweets', 'likes',
#        'attachments', 'replies'],
#       dtype='object')
# ...

# %%
display(tweetData)
print(len(tweetData))
# Out:
# [{'created_at': '2022-06-18 05:10:02+00:00',
#   'id': 1538026227767791617,
#   'text': 'my bestie got this for me lol I need it today @SajeWellness #stressed https://t.co/q61M0sSo3O',
#   'source': 'Twitter for iPhone',
#   'name': 'Doc Chits',
#   'username': 'thechitspobar17',
#   'location': nan,
#   'verified': False,
#   'description': 'Licensed to Heal | Family Physician in Training',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1536561770726576128/gZoTRy3l_normal.jpg',
#   'retweets': 0,
#   'likes': 5,
#   'attachments': "['https://pbs.twimg.com/media/FVgqsz4UEAAFHlC.jpg - 2048x2048 - Alt: None']",
#   'replies': '{"data":[{"id":"1538913640228716544","text":"@starseedjazzy Such a perfect combination \\uD83D\\uDC9A"}],"meta":{"newest_id":"1538913640228716544","oldest_id":"1538913640228716544","result_count":1}}'},
#  {'created_at': '2022-06-18 02:31:03+00:00',
#   'id': 1537986217295216641,
#   'text': 'Finally watching  #Ozark  finale. #stressed',
# ...

# %%
#unprocessed_list=removeUnWantedData(dataFrame)
# Out:
#                     created_at                   id  \
# 20   2022-06-21 17:35:06+00:00  1539300891643232258
# 25   2022-06-21 15:20:41+00:00  1539267065550454785
# 47   2022-06-21 05:43:17+00:00  1539121758392963073
# 52   2022-06-21 02:10:05+00:00  1539068103891509248
# 55   2022-06-20 22:32:25+00:00  1539013329041215490
# 56   2022-06-20 20:45:07+00:00  1538986326955106304
# 58   2022-06-20 20:10:29+00:00  1538977608037109760
# 59   2022-06-20 19:43:40+00:00  1538970861285298177
# 62   2022-06-20 17:27:40+00:00  1538936636003655682
# 86   2022-06-19 23:52:00+00:00  1538670967748235264
# 99   2022-06-19 14:22:27+00:00  1538527634686103555
# 120  2022-06-21 17:35:06+00:00  1539300891643232258
# 125  2022-06-21 15:20:41+00:00  1539267065550454785
# 147  2022-06-21 05:43:17+00:00  1539121758392963073
# 152  2022-06-21 02:10:05+00:00  1539068103891509248
# 155  2022-06-20 22:32:25+00:00  1539013329041215490
# 156  2022-06-20 20:45:07+00:00  1538986326955106304
# ...

# %%
#from_many_replies_reretrived.to_csv(r'from_many_replies_reretrived.csv',index = False, header=True)
dataFrame.to_csv(r'from_many_replies_reretrived_23_06.csv',index = False, header=True)

# %%
print(len(previous_clean_replies),len(dataFrame))
# Out:
# 44 495

# %%
# merged_tweet_with_replies = pd.concat([clean_replies_df, from_many_replies_reretrived])
previous_clean_replies=pd.read_csv("clean_replies_from_first_cleared_22_06_data.csv")
#display(previous_clean_replies)
# merged_tweet_with_replies = pd.concat([clean_replies_df, dataFrame])
merged_tweet_with_replies = pd.concat([previous_clean_replies, dataFrame])
display(merged_tweet_with_replies)
# merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only.csv',index = False, header=True)
merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only_23_06.csv',index = False, header=True)
# Out:
#                     created_at                   id  \
# 0    2022-06-21 17:35:06+00:00  1539300891643232258
# 1    2022-06-21 15:20:41+00:00  1539267065550454785
# 2    2022-06-21 05:43:17+00:00  1539121758392963073
# 3    2022-06-21 02:10:05+00:00  1539068103891509248
# 4    2022-06-20 22:32:25+00:00  1539013329041215490
# ..                         ...                  ...
# 490  2022-06-18 11:55:34+00:00  1538128284353024003
# 491  2022-06-18 07:10:28+00:00  1538056534319677442
# 492  2022-06-18 07:01:48+00:00  1538054353692639236
# 493  2022-06-18 07:01:46+00:00  1538054347380203523
# 494  2022-06-18 07:01:45+00:00  1538054343387226113
#
#                                                   text               source  \
# 0    Count to ten I need to count to 100 🙄🙄🙄The cha...  Twitter for Android
# 1    Mine and my family's should b here by Friday i...  Twitter for Android
# 2    This father’s land don tire me to serve oo😒#st...   Twitter for iPhone
# ...

# %%
cleaned_tweet_data_23_06 =merged_tweet_with_replies.drop_duplicates()
print(len(cleaned_tweet_data_23_06))
unprocesed_23_06,returnedFile=removeUnWantedData(cleaned_tweet_data_23_06,"procesed_23_06.csv")
print(len(unprocesed_23_06))
# Out:
# 499
#                     created_at                   id  \
# 0    2022-06-21 17:35:06+00:00  1539300891643232258
# 1    2022-06-21 15:20:41+00:00  1539267065550454785
# 2    2022-06-21 05:43:17+00:00  1539121758392963073
# 3    2022-06-21 02:10:05+00:00  1539068103891509248
# 4    2022-06-20 22:32:25+00:00  1539013329041215490
# 5    2022-06-20 20:45:07+00:00  1538986326955106304
# 6    2022-06-20 20:10:29+00:00  1538977608037109760
# 7    2022-06-20 19:43:40+00:00  1538970861285298177
# 8    2022-06-20 17:27:40+00:00  1538936636003655682
# 9    2022-06-19 23:52:00+00:00  1538670967748235264
# 10   2022-06-19 14:22:27+00:00  1538527634686103555
# 11   2022-06-21 17:35:06+00:00  1539300891643232258
# 12   2022-06-21 15:20:41+00:00  1539267065550454785
# 13   2022-06-21 05:43:17+00:00  1539121758392963073
# 14   2022-06-21 02:10:05+00:00  1539068103891509248
# 15   2022-06-20 22:32:25+00:00  1539013329041215490
# 16   2022-06-20 20:45:07+00:00  1538986326955106304
# ...

# %%
tweetData_23_6=proccessUnproccessed(unprocesed_23_06)
display(tweetData_23_6)
dataFrame_23_06=pd.DataFrame(tweetData_23_6)
display(dataFrame_23_06)
# Out:
# Index(['created_at', 'id', 'text', 'source', 'name', 'username', 'location',
#        'verified', 'description', 'profile_image_url', 'retweets', 'likes',
#        'attachments', 'replies'],
#       dtype='object')
# {'created_at': '2022-06-18 07:01:46+00:00', 'id': 1538054347380203523, 'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n "The Wire" at 20: …', 'source': 'IFTTT', 'name': 'Doc Chits', 'username': 'thechitspobar17', 'location': nan, 'verified': False, 'description': 'Licensed to Heal | Family Physician in Training', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1536561770726576128/gZoTRy3l_normal.jpg', 'retweets': 0, 'likes': 0, 'attachments': '[]', 'replies': '{"meta":{"result_count":0}}'}
# ...

# %%
returnedFileDF=pd.read_csv(returnedFile)
display(returnedFileDF)
# Out:
#                    created_at                   id  \
# 0   2022-06-21 17:35:06+00:00  1539300891643232258
# 1   2022-06-21 15:20:41+00:00  1539267065550454785
# 2   2022-06-21 05:43:17+00:00  1539121758392963073
# 3   2022-06-21 02:10:05+00:00  1539068103891509248
# 4   2022-06-20 22:32:25+00:00  1539013329041215490
# 5   2022-06-20 20:45:07+00:00  1538986326955106304
# 6   2022-06-20 20:10:29+00:00  1538977608037109760
# 7   2022-06-20 19:43:40+00:00  1538970861285298177
# 8   2022-06-20 17:27:40+00:00  1538936636003655682
# 9   2022-06-19 23:52:00+00:00  1538670967748235264
# 10  2022-06-19 14:22:27+00:00  1538527634686103555
# 11  2022-06-21 17:35:06+00:00  1539300891643232258
# 12  2022-06-21 15:20:41+00:00  1539267065550454785
# 13  2022-06-21 05:43:17+00:00  1539121758392963073
# 14  2022-06-21 02:10:05+00:00  1539068103891509248
# 15  2022-06-20 22:32:25+00:00  1539013329041215490
# 16  2022-06-20 20:45:07+00:00  1538986326955106304
# ...

# %%
uproccessedNow,savedFile=removeUnWantedData(dataFrame_23_06,'23_06_proccessedData.csv')
# Out:
# Empty DataFrame
# Columns: [created_at, id, text, source, name, username, location, verified, description, profile_image_url, retweets, likes, attachments, replies]
# Index: []

# %%
returnedFileDF=pd.read_csv(savedFile)
display(returnedFileDF)
# Out:
# Empty DataFrame
# Columns: [created_at, id, text, source, name, username, location, verified, description, profile_image_url, retweets, likes, attachments, replies]
# Index: []

# %%
print(len(uproccessedNow))
print(savedFile)
display(uproccessedNow)
newDF=pd.read_csv('23_06_proccessedData.csv')
#By now every data is proccessed
# Out:
# 0
# 23_06_proccessedData.csv
# Empty DataFrame
# Columns: [created_at, id, text, source, name, username, location, verified, description, profile_image_url, retweets, likes, attachments, replies]
# Index: []

# %%
display(newDF)
print(len(newDF))
print(len(uproccessedNow))
# Out:
# Empty DataFrame
# Columns: [created_at, id, text, source, name, username, location, verified, description, profile_image_url, retweets, likes, attachments, replies]
# Index: []
# 0
# 0

# %%
tweetData_23_6=proccessUnproccessed(uproccessedNow)
display(tweetData_23_6)
dataFrame_23_06=pd.DataFrame(tweetData_23_6)
display(dataFrame_23_06)
uproccessedNow,savedFile=removeUnWantedData(dataFrame_23_06,'23_06_1_proccessedData.csv')
# Out:
# Index(['created_at', 'id', 'text', 'source', 'name', 'username', 'location',
#        'verified', 'description', 'profile_image_url', 'retweets', 'likes',
#        'attachments', 'replies'],
#       dtype='object')
# ...

# %%
print(len(dataFrame_23_06))
print(len(uproccessedNow))
display(uproccessedNow)
# Out:
# 495
# 495
#                      created_at                   id  \
# 350   2022-06-18 05:10:02+00:00  1538026227767791617
# 351   2022-06-18 02:31:03+00:00  1537986217295216641
# 352   2022-06-18 01:40:15+00:00  1537973434218467330
# 353   2022-06-17 23:38:55+00:00  1537942900465467394
# 354   2022-06-17 23:36:45+00:00  1537942353230475264
# ...                         ...                  ...
# 1832  2022-06-18 11:55:34+00:00  1538128284353024003
# 1833  2022-06-18 07:10:28+00:00  1538056534319677442
# 1834  2022-06-18 07:01:48+00:00  1538054353692639236
# 1836  2022-06-18 07:01:46+00:00  1538054347380203523
# 1837  2022-06-18 07:01:45+00:00  1538054343387226113
#
#                                                    text              source  \
# 350   my bestie got this for me lol I need it today ...  Twitter for iPhone
# 351         Finally watching  #Ozark  finale. #stressed  Twitter for iPhone
# 352   Is it bad I wanna start doing stuff Inee never...  Twitter for iPhone
# ...

# %%
display(dataFrame_23_06)
cleaned_tweet_data=dataFrame_23_06.drop_duplicates()
unprocesed = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])]
# Out:
#                     created_at                   id  \
# 0    2022-06-18 05:10:02+00:00  1538026227767791617
# 1    2022-06-18 02:31:03+00:00  1537986217295216641
# 2    2022-06-18 01:40:15+00:00  1537973434218467330
# 3    2022-06-17 23:38:55+00:00  1537942900465467394
# 4    2022-06-17 23:36:45+00:00  1537942353230475264
# ..                         ...                  ...
# 490  2022-06-18 11:55:34+00:00  1538128284353024003
# 491  2022-06-18 07:10:28+00:00  1538056534319677442
# 492  2022-06-18 07:01:48+00:00  1538054353692639236
# 493  2022-06-18 07:01:46+00:00  1538054347380203523
# 494  2022-06-18 07:01:45+00:00  1538054343387226113
#
#                                                   text              source  \
# 0    my bestie got this for me lol I need it today ...  Twitter for iPhone
# 1          Finally watching  #Ozark  finale. #stressed  Twitter for iPhone
# 2    Is it bad I wanna start doing stuff Inee never...  Twitter for iPhone
# ...

# %% [markdown]
# DATA  : FROM
# start_time = "2022-06-09T00:00:00Z"
# end_time = "2022-06-15T00:00:00Z"

# %%
display(unprocesed)
# Out:
#                     created_at                   id  \
# 450  2022-06-19 08:35:15+00:00  1538440261587566593
# 451  2022-06-19 07:01:51+00:00  1538416753348313089
# 452  2022-06-19 07:01:50+00:00  1538416750345261056
# 453  2022-06-19 07:01:50+00:00  1538416749107740672
# 454  2022-06-19 07:01:49+00:00  1538416748164046849
# 455  2022-06-19 07:01:49+00:00  1538416745467232258
# 456  2022-06-19 07:01:48+00:00  1538416742707372033
# 457  2022-06-19 07:01:47+00:00  1538416739796627457
# 458  2022-06-19 07:01:47+00:00  1538416737632272385
# 459  2022-06-19 05:52:03+00:00  1538399187896778752
# 460  2022-06-19 04:57:03+00:00  1538385348513959936
# 461  2022-06-19 04:10:38+00:00  1538373668484554753
# 462  2022-06-19 03:40:24+00:00  1538366059513892864
# 463  2022-06-19 03:38:08+00:00  1538365489260404736
# 464  2022-06-19 03:37:46+00:00  1538365396947968001
# 465  2022-06-19 03:35:20+00:00  1538364785468792832
# 466  2022-06-19 03:33:19+00:00  1538364274640359425
# ...

# %%
print(len(unprocesed))
# Out:
# 45

# %%
tweetData_23_6=proccessUnproccessed(unprocesed)
display(tweetData_23_6)
dataFrame_23_06=pd.DataFrame(tweetData_23_6)
display(dataFrame_23_06)
# Out:
# Index(['created_at', 'id', 'text', 'source', 'name', 'username', 'location',
#        'verified', 'description', 'profile_image_url', 'retweets', 'likes',
#        'attachments', 'replies'],
#       dtype='object')
# {'created_at': '2022-06-19 08:35:15+00:00', 'id': 1538440261587566593, 'text': 'Black Rabbit - Easy Self-Confidence Guided Meditation/Self-hypnosis #confidence #stress #stressrelief #stressmanagement #stressed #meditation \nhttps://t.co/TFPlcthkDh', 'source': 'Twitter Web App', 'name': 'Shawna', 'username': 'Sha_Nikki', 'location': 'Thanks for all the fish, OH', 'verified': False, 'description': 'Fun, sarcastic, sweet, outgoing but shy (ironic, eh), sarcastic, hilarious, random, kind, LOVES books and music, and beware of the sarcasm!', 'profile_image_url': 'https://pbs.twimg.com/profile_images/498112515507638272/Y_TbeKRf_normal.jpeg', 'retweets': 0, 'likes': 0, 'attachments': '[]', 'replies': '{"meta":{"result_count":0}}'}
# ...

# %%
uproccessedNow,savedFile=removeUnWantedData(dataFrame_23_06,'23_06_1_1_proccessedData.csv')
display(uproccessedNow)
# Out:
#                    created_at                   id  \
# 11  2022-06-19 04:10:38+00:00  1538373668484554753
# 17  2022-06-19 03:03:32+00:00  1538356780203397120
# 26  2022-06-18 19:51:54+00:00  1538248157955489793
# 37  2022-06-18 15:25:12+00:00  1538181038815342592
# 41  2022-06-18 07:10:28+00:00  1538056534319677442
#
#                                                  text              source  \
# 11                          2-day migraine. #stressed  Twitter for iPhone
# 17  @SouthernRailUK what’s going on? We are stuck ...  Twitter for iPhone
# 26  Literally crying because I haven’t eaten an ac...  Twitter for iPhone
# 37  Brain: Be depressed. \nMe: dude, no. Not today...  Twitter for iPhone
# 41  clearing my head #stressed https://t.co/foNfV3...     Twitter Web App
#
#       name   username                     location  verified  \
# 11  Shawna  Sha_Nikki  Thanks for all the fish, OH     False
# 17  Shawna  Sha_Nikki  Thanks for all the fish, OH     False
# ...

# %%
print(len(uproccessedNow))
# Out:
# 0
