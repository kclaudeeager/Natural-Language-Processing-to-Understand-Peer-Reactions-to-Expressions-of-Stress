# %%
data_list=list(dict())
all_users=[dict()]
media={}
def getAllTweetsData(response):
    # process users
    global data_list
    global all_users
    users = {}
    tweet_user=[]
   
    all_tweet_list=list()
# tweet specific info
    response.includes.setdefault('media',None)
    for user in response.includes['users']:
    # print(user.username)
    # print(user.name)
        users[user.id] = f"{user.name} (@{user.username}) [{user.profile_image_url}]"
        print(users[user.id])
        #print("User:>>>>>>",{user})
        #all_users.append({user})
    # print(dir(inclu))
 
# process media attachment

    global media
    if response.includes['media'] is not None:
        for item in response.includes['media']:
            media[item.media_key] = f"{item.url} - {item.height}x{item.width} - Alt: {item.alt_text}"
            print(media[item.media_key])
 
 
    tweets = response.data
 
# The expanded tweet offers a lot more data
    for tweet in tweets:
        print("type of the tweet:>>>>",type(tweet))
        data_list.append(dict(tweet))
        print('-' * 50)
        print(f"{tweet.id} ({tweet.created_at}) - {users[tweet.author_id]}:\n {tweet.text} \n")
        metric = tweet.public_metrics
        print(f"retweets: {metric['retweet_count']} | likes: {metric['like_count']}")
        if tweet.attachments is not None:
            for media_key in tweet.attachments['media_keys']:
                print(f"Media attachment: {media[media_key]}")

# %%
import tweepy
import requests

# your bearer token
MY_BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D"
# create your client 
client = tweepy.Client(bearer_token=MY_BEARER_TOKEN)
# query to search for tweets
query = "#stressed lang:en -is:retweet"
next_token={}
conversationIds=list()
tweet_ids=list()
# your start and end time for fetching tweets
start_time = "2022-06-09T00:00:00Z"
end_time = "2022-06-15T00:00:00Z"
user_list=[]
#MY_BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D"
# create your client 
client = tweepy.Client(bearer_token=MY_BEARER_TOKEN)


next_token={}
tweet_fields = ["created_at", "text", "source","id",'attachments',"author_id","in_reply_to_user_id","geo","conversation_id","lang","public_metrics","referenced_tweets","reply_settings","source"]
res = []
for i in tweet_fields:
    if i not in res:
        res.append(i)
def run_response():
    global next_token
    response = client.search_recent_tweets(
                "#stressed lang:en -is:retweet", 
                start_time=start_time,
                end_time=end_time,
                max_results=100,
                expansions="author_id,attachments.media_keys,in_reply_to_user_id,geo.place_id",
                tweet_fields=res,
                user_fields="created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld",
                next_token=next_token,
                media_fields="public_metrics,url,height,width,alt_text")
    response.meta.setdefault('next_token',None)
    if response.meta is not None:
        next_token={response.meta['next_token']}
    getAllTweetsData(response)
    #print('Next token :',next_token)
    i=0
    for tweet in response.data:
    
   
    # user information for the first tweet
        tweet_user=response.includes["users"][i]
        all_users.append(dict(tweet_user))
        #print(dict(tweet_user)," <<<User\n ____________________________________________________________________________\n\n")
        #print(dict(tweet),"\n\n")
        dict_tweet = dict(tweet)
        print(dict_tweet.keys())
        print('---------------------------------')
        data_list.append(dict(tweet))
        ++i
        tweetId=tweet.id
        tweet_ids.append(tweetId)
        q=tweet.conversation_id
        conversationIds.append(q)


for i in range(0,100):
    run_response()

# %%
import requests
import time
def fetchReplies(tweetId):
      
  time.sleep(1) 
  payload = ""
  headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAADCKdQEAAAAAp5B7riMWUn8ZPFmeXL%2FFFVSDmp4%3DTpJL8eN4a8HJ35nCs8xd8j2UlprTafjY4iPXTQijKjvSrXBM3D',
    'Cookie': 'guest_id=v1%3A165461133818653501; guest_id_ads=v1%3A165461133818653501; guest_id_marketing=v1%3A165461133818653501; personalization_id="v1_2aA81CEcKTHAJ4Cp/ipjcg=="'
  }
  url = "https://api.twitter.com/2/tweets/search/recent?query=conversation_id:"+str(tweetId)
  response = requests.request("GET", url, headers=headers, data=payload)
  return response.text

# %%
import time
class TimerClass:
# Timer starts

    starttime = time.time()
    lasttime = starttime
    lapnum = 1
    value = ""
    
    print("Press ENTER for each lap.\nType Q and press ENTER to stop.")

    def getUsedTime(self):
        valueDict=dict()
        # global value,starttime,lasttime,lapnum
        m=s=h=0.00
        while self.value.lower() != "q":
                    
            # Input for the ENTER key press
            self.value = input()
        
            # The current lap-time
            self.laptime = round((time.time() - self.lasttime), 2)
        
            # Total time elapsed since the timer started
            self.totaltime = round((time.time() - self.starttime), 2)
            m, s = divmod(self.laptime, 60)
            h, m = divmod(m, 60)
            # Printing the lap number, lap-time, and total time
            #print(f'{h:d}:{m:02d}:{s:02d}')
            print("Lap No. "+str(self.lapnum))
            print("Total Time: "+str(self.totaltime))
            # print("Lap Time: "+str(laptime))
            print(m)
            print('{:f}:{:02f}:{:02f}'.format(h, m, s))
                    
            print("*"*20)
        
            # Updating the previous total time and lap number
            lasttime = time.time()
            self.lapnum += 1
            valueDict={"hr":h,"min":m,"sec":s,"total":self.totaltime,"times":self.lapnum}
        return valueDict

# %%
# create a list of records
tweet_info_ls = []
new_user_list=list(dict())
newDataList=[{}]
#print(len(all_users))
#print('all users: ',all_users)

for user_data in all_users:
    #print(user_data,'\n__________________________________________________________________________________________________________________________________________________________________________________________________________________________\n')
    if user_data=={}:
        all_users.remove(user_data)
#print("user size",len(all_users))
#Remove duplicates
for user in all_users:
    if user not in new_user_list:
        new_user_list.append(user)
for tweetData in data_list:
    if tweetData not in newDataList:
        newDataList.append(tweetData)

# %%
# import the pandas library
import pandas as pd
from time import sleep

#print("data size : ",len(data_list))
# iterate over each tweet and corresponding user details
k=0
startTime=time.time()
totalUsers=len(all_users)
print(totalUsers)
print(startTime)
for tweet, user in zip(data_list, all_users):
    difference=0
    #print(user)
    print("k is ",k)
    print('...................................................................')
    user.setdefault('location', "")
    attachments=[]
    #print(media)
    tweet.setdefault('attachments',None)
    found_attachment=tweet['attachments']
    print(tweet)
    if found_attachment is not None:
        #print(found_attachment,'\n___________________________________________________________________')

        
        for media_key in found_attachment['media_keys']:
            attachment= media[media_key]
            print(attachment)
            attachments.append(attachment)
    #print(attachments)  
    metric=tweet['public_metrics']
    replies=fetchReplies(tweet['id'])
    tweet_info = {
        'created_at': tweet['created_at'],
        'id':tweet['id'],
        'text': tweet['text'],
        'source': tweet['source'],
        'name': user['name'],
        'username': user['username'],
        'location': user['location'],
        'verified': user['verified'],
        'description': user['description'],
        'profile_image_url':user['profile_image_url'],
        'retweets':metric['retweet_count'],
        'likes':metric['like_count'],
        'attachments':attachments,
        'replies':replies
          
    }
    print(tweet_info)
    tweet_info_ls.append(tweet_info)
    if k==20:
        print("Now k is:>>>>>>>>>>>>>>>>",k)
        difference=round(time.time()-startTime,2)
        m, s = divmod(difference, 60)            
        h, m = divmod(m, 60)
        if m<15:
            k=0
            sleep((15-m)*60)
            
            startTime=time.time()
    k=k+1

# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
display(tweets_df)
#print(midea['1535705930641207296'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\University of Michigan\Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress\main.ipynb Cell 8' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=4'>5</a> #print("data size : ",len(data_list))
#       <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=5'>6</a> # iterate over each tweet and corresponding user details
#       <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=6'>7</a> k=0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=7'>8</a> startTime=time.time()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=8'>9</a> totalUsers=len(all_users)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/University%20of%20Michigan/Natural-Language-Processing-to-Understand-Peer-Reactions-to-Expressions-of-Stress/main.ipynb#ch0000007?line=9'>10</a> print(totalUsers)
#
# NameError: name 'time' is not defined

# %%
import csv


tweets_df.to_csv(r'newRetrievedData.csv',index = False, header=True)

newRetrievedData_cleared_df =pd.read_csv('newRetrievedData.csv')
replies = newRetrievedData_cleared_df["replies"] 
#print(replies)
#display(replies)
#print(len(tweets_df["replies"].value_counts()))

# %%
import csv


tweets_df.to_csv(r'twitterDataWithReplies.csv',index = False, header=True)

cleared_df =pd.read_csv('twitterDataWithReplies.csv')
replies = cleared_df["replies"] 

print(len(cleared_df["replies"].value_counts()))
# Out:
# 41

# %%
# remove duplicates
import csv
import pandas as pd


# tweets_df.to_csv(r'twitterData.csv',index = False, header=True)
tweet_data = pd.read_csv("twitterDataWithReplies.csv")
print(len(tweet_data))
# display(tweet_data)
cleaned_tweet_data = tweet_data.drop_duplicates()
# print(len(cleaned_tweet_data))
# display(cleaned_tweet_data)
no_reply = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}'])]
# display(no_reply)
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
unprocesed = cleaned_tweet_data[cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])]
# display(unprocesed["id"])
no_reply_and_unp = cleaned_tweet_data['replies'].isin(['{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}', '{"meta":{"result_count":0}}'])
# print(f"total doc : {len(cleaned_tweet_data)}, with no reply : {len(no_reply)} , unprocessed : {len(unprocesed)} ")
# print("with replay : ",len(cleaned_tweet_data) -(len(no_reply) + len(unprocesed)))

clean_replies = ~ cleaned_tweet_data['replies'].isin(['{"meta":{"result_count":0}}','{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])
clean_replies_df = cleaned_tweet_data[clean_replies]
display(clean_replies_df)
# Out:
# 9802
#                      created_at                   id  \
# 0     2022-06-13 22:56:56+00:00  1536482781139705857
# 9     2022-06-13 18:47:52+00:00  1536420101230141446
# 23    2022-06-13 15:33:42+00:00  1536371239723360257
# 24    2022-06-13 15:17:14+00:00  1536367096954621954
# 26    2022-06-13 14:21:47+00:00  1536353140173324291
# ...                         ...                  ...
# 1135  2022-06-08 11:10:26+00:00  1534493047857328130
# 1622  2022-06-08 13:54:01+00:00  1534534213021614085
# 1716  2022-06-08 13:54:01+00:00  1534534213021614085
# 6326  2022-06-08 13:54:01+00:00  1534534213021614085
# 6420  2022-06-08 13:54:01+00:00  1534534213021614085
#
#                                                    text               source  \
# 0                            good night im #stressed xx   Twitter for iPhone
# 9     I have another flight tomorrow.. would you hel...  Twitter for Android
# 23    This life has really beaten me down and now I'...  Twitter for Android
# 24      Home alone and I can’t find my 🌹! #Stressed 😂😂😂   Twitter for iPhone
# 26    🚨Hoping for a good day. I've got so much that ...  Twitter for Android
# ...                                                 ...                  ...
# 1135  @matalan now confirming my order was infact in...   Twitter for iPhone
# 1622  Look at that, a year ago today since I paid my...   Twitter for iPhone
# 1716  Look at that, a year ago today since I paid my...   Twitter for iPhone
# 6326  Look at that, a year ago today since I paid my...   Twitter for iPhone
# 6420  Look at that, a year ago today since I paid my...   Twitter for iPhone
#
#                         name        username  \
# 0     ‎ً ★ mar’s fiancé ?! 2    tobesocharly
# 9     ‎ً ★ mar’s fiancé ?! 2    tobesocharly
# 23    ‎ً ★ mar’s fiancé ?! 2    tobesocharly
# 24    ‎ً ★ mar’s fiancé ?! 2    tobesocharly
# 26    ‎ً ★ mar’s fiancé ?! 2    tobesocharly
# ...                      ...             ...
# 1135      TrustedHealth.Info  TrustHealthInf
# 1622         Christine Sipka         Freonut
# 1716      TrustedHealth.Info  TrustHealthInf
# 6326         Christine Sipka         Freonut
# 6420      TrustedHealth.Info  TrustHealthInf
#
#                                                location  verified  \
# 0     my policeman enthusiast     ⌗1 Nana’s House st...     False
# 9     my policeman enthusiast     ⌗1 Nana’s House st...     False
# 23    my policeman enthusiast     ⌗1 Nana’s House st...     False
# 24    my policeman enthusiast     ⌗1 Nana’s House st...     False
# 26    my policeman enthusiast     ⌗1 Nana’s House st...     False
# ...                                                 ...       ...
# 1135                                                NaN     False
# 1622                                           Brisbane     False
# 1716                                                NaN     False
# 6326                                           Brisbane     False
# 6420                                                NaN     False
#
#                                             description  \
# 0     ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 9     ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 23    ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 24    ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 26    ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# ...                                                 ...
# 1135                         Trusted Health Information
# 1622  Family * Gaming * Footy * Uni \nYou are beauti...
# 1716                         Trusted Health Information
# 6326  Family * Gaming * Footy * Uni \nYou are beauti...
# 6420                         Trusted Health Information
#
#                                       profile_image_url  retweets  likes  \
# 0     https://pbs.twimg.com/profile_images/153374527...         0      0
# 9     https://pbs.twimg.com/profile_images/153374527...         0      9
# 23    https://pbs.twimg.com/profile_images/153374527...         0      3
# 24    https://pbs.twimg.com/profile_images/153374527...         0      0
# 26    https://pbs.twimg.com/profile_images/153374527...         1      0
# ...                                                 ...       ...    ...
# 1135  https://pbs.twimg.com/profile_images/131177466...         0      0
# 1622  https://pbs.twimg.com/profile_images/552733105...         0      0
# 1716  https://pbs.twimg.com/profile_images/131177466...         0      0
# 6326  https://pbs.twimg.com/profile_images/552733105...         0      0
# 6420  https://pbs.twimg.com/profile_images/131177466...         0      0
#
#                                             attachments  \
# 0                                                    []
# 9     ['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro....
# 23                                                   []
# 24                                                   []
# 26                                                   []
# ...                                                 ...
# 1135                                                 []
# 1622  ['https://pbs.twimg.com/media/FUvCu7MWIAITPNa....
# 1716  ['https://pbs.twimg.com/media/FUvCu7MWIAITPNa....
# 6326  ['https://pbs.twimg.com/media/FUvCu7MWIAITPNa....
# 6420  ['https://pbs.twimg.com/media/FUvCu7MWIAITPNa....
#
#                                                 replies
# 0     {"data":[{"id":"1536487441468727297","text":"@...
# 9     {"data":[{"id":"1536483956304093185","text":"@...
# 23    {"data":[{"id":"1536407609988849672","text":"@...
# 24    {"data":[{"id":"1536369878608842753","text":"@...
# 26    {"data":[{"id":"1536353141624655873","text":"I...
# ...                                                 ...
# 1135  {"data":[{"id":"1534502889518940166","text":"@...
# 1622  {"data":[{"id":"1536684479720443907","text":"@...
# 1716  {"data":[{"id":"1536684479720443907","text":"@...
# 6326  {"data":[{"id":"1536709197248745472","text":"@...
# 6420  {"data":[{"id":"1536709197248745472","text":"@...
#
# [78 rows x 14 columns]

# %%
clean_replies_df.to_csv(r'clean_replies_from_first_cleared_data.csv',index = False, header=True)

# %%
# unprocessed df to list 
unprocesed_list = []
print(unprocesed.columns)
for index, tweet in unprocesed.iterrows():
    new_unp =  {
        'created_at': tweet['created_at'],
        'id':tweet['id'],
        'text': tweet['text'],
        'source': tweet['source'],
        'name': tweet['name'],
        'username': tweet['username'],
        'location': tweet['location'],
        'verified': tweet['verified'],
        'description': tweet['description'],
        'profile_image_url':tweet['profile_image_url'],
        'retweets':tweet['retweets'],
        'likes':tweet['likes'],
        'attachments':tweet['attachments'],
        'replies':tweet['replies']
    }
    unprocesed_list.append(new_unp)
display(unprocesed_list)
replies_list=[]
for tweetData in unprocesed_list:
    reply=fetchReplies(tweetData['id'])
    replies_list.append(reply)
    tweetData['replies']=reply
    print(reply)
# Out:
# Index(['created_at', 'id', 'text', 'source', 'name', 'username', 'location',
#        'verified', 'description', 'profile_image_url', 'retweets', 'likes',
#        'attachments', 'replies'],
#       dtype='object')
# [{'created_at': '2022-06-08 12:51:46+00:00',
#   'id': 1534518548718026753,
#   'text': 'Women shouldn’t have to work on their period. #ISaidWhatISaid #Stressed #Women',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 12:39:52+00:00',
#   'id': 1534515552672096257,
#   'text': 'My little buddy Beans hanging out with me while we watch ghost shows. He is such a good emotional support cat, cause man I am #Stressed https://t.co/lx8OGytgzt',
#   'source': 'Twitter for Android',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 2,
#   'attachments': "['https://pbs.twimg.com/media/FUuxwdrUsAAIeG7.jpg - 2048x1339 - Alt: None']",
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 12:00:02+00:00',
#   'id': 1534505529057456128,
#   'text': 'Need to de-stress? Ditch the stress ball and just smile more! Find out what else a smile can do for your health: https://t.co/r56CLGYHEM.\n.\n.\n#stress #smile #stressed #stressfree #wellbeing #health #happy #kamaldentalclinic',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 11:10:26+00:00',
#   'id': 1534493047857328130,
#   'text': '@matalan now confirming my order was infact in stock but they still cancelled it….???? I do not have time to re-order all this!! Jason Hargreaves this needs to be dealt with! #Stressed https://t.co/Pysqm1sYb7',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 10:50:04+00:00',
#   'id': 1534487921629462528,
#   'text': 'Do you feel #stressed and is it affecting your #Mentalhealth give us a call, we cover all of Wales and we can #help #support and #signpost CALL 24/7 - Mental Health Wales on 0800 132 737 or text HELP to 81066..(gw)  \nApril is National Stress Awareness Month 2019  #StressAwareness https://t.co/pX8x5rUIe5',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 2,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 09:46:40+00:00',
#   'id': 1534471966739922944,
#   'text': 'Massive workload and tight deadlines are my life at the moment. Staffing shortages from high resignations couple with insane recruiting market and heaps of staff away with COVID and flu.  Is this how work is going to be now? Or is there an end point? \n#jobs #stressed',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 08:59:25+00:00',
#   'id': 1534460076932870144,
#   'text': "What's ur fav subject?? For me it's science and maths but sometimes I really like the subject and sometimes I hate it .. 🥲 studying is hard 🥲🥲\n#stressed and #depressed https://t.co/kHZaC0lNzn",
#   'source': 'Twitter for Android',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 1,
#   'attachments': "['None - 324x480 - Alt: None']",
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 08:31:00+00:00',
#   'id': 1534452925455532033,
#   'text': 'Stressful Tuesday on to a stressful Wednesday 10 hours travelling 🚖✈️🚕 traffic delays  fiasco at Luton Airport on arrival “All male passenger must remain on board” 😳 #police #tired #stressed #airportchaos',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:19:17+00:00',
#   'id': 1534434873909338113,
#   'text': '5 Ways To Prevent Stress Buildup\n#stress #stressed #stressawarenessmonth #PreventStress\n\nhttps://t.co/N8XOuFE4TH',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:52+00:00',
#   'id': 1534430491717341185,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Review: Sarah Silv…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:51+00:00',
#   'id': 1534430489762734080,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Philadelphia Museu…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:51+00:00',
#   'id': 1534430487803985920,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Barbara Pym: An ex…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:50+00:00',
#   'id': 1534430485140602886,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Martha Myers, who …',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:49+00:00',
#   'id': 1534430481680322560,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n “Dear Evan Hansen”…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:48+00:00',
#   'id': 1534430476986994693,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Ruth Negga thinks …',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:48+00:00',
#   'id': 1534430474222944256,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Jim Seals, one hal…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:47+00:00',
#   'id': 1534430471936950272,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n George Shapiro, ta…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:47+00:00',
#   'id': 1534430470141882369,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Shell, the oil gia…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:46+00:00',
#   'id': 1534430468137000960,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Matthew McConaughe…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:46+00:00',
#   'id': 1534430466564149248,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Hiring remains str…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:45+00:00',
#   'id': 1534430464643149825,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Geraldine Brooks, …',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:45+00:00',
#   'id': 1534430462839488512,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n How iOS 16 and And…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:44+00:00',
#   'id': 1534430459832172551,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Breast cancer drug…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:43+00:00',
#   'id': 1534430456606769154,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Caviar “bumps” are…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:43+00:00',
#   'id': 1534430453888958465,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Questions from rea…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:42+00:00',
#   'id': 1534430451359703040,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n FDA advisers meet …',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:41+00:00',
#   'id': 1534430448620822528,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Disney apologizes …',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:41+00:00',
#   'id': 1534430446486007808,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Golden State defea…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:40+00:00',
#   'id': 1534430443667341312,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n In the NHL playoff…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:40+00:00',
#   'id': 1534430441306050561,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Nadal has a chance…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:39+00:00',
#   'id': 1534430437862281216,
#   'text': "#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLvG61\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Mets' Eduardo Esco…",
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:38+00:00',
#   'id': 1534430432921518082,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Dustin Johnson res…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:37+00:00',
#   'id': 1534430430555947008,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Have you sold your…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 07:01:36+00:00',
#   'id': 1534430427515170818,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Ukraine-Russia War…',
#   'source': 'IFTTT',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 05:30:19+00:00',
#   'id': 1534407452686360576,
#   'text': 'Crypto got you #stressed ? Try listening to relaxing rain sounds ⬇️⬇️\n\n#btc #xrp #xlm #luna #terraluna #bitcoin #Ethereum \n\nhttps://t.co/sZAgIajHaW',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 05:14:35+00:00',
#   'id': 1534403492818964481,
#   'text': 'Between student debt, my bills and these gas prices…. Stripping really not sounding like a bad idea #gasprices #CancelStudentDebt #stressed',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 3,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 04:32:03+00:00',
#   'id': 1534392790871904256,
#   'text': 'Gary Zimak on de-stressing and @Ed VanBuskirck on the joy of the 10 Commandments and then Fufeng news. #Catholic #God #Jesus #Stressed #Fufeng @gary_zimak @ifuloveme18 https://t.co/yYIH5haYEI',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 1,
#   'likes': 1,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 04:31:31+00:00',
#   'id': 1534392657837019136,
#   'text': 'yk its already gon be a bad day when the hms groupchat starts typing #STRESSED',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 4,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 04:21:11+00:00',
#   'id': 1534390057070641158,
#   'text': 'So much fun talking with Gary Zimak on getting rid of stress and  Ed VanBuskirck on the 10 Commandments and then Fufeng news. #Catholic #God #Jesus #Stressed #Fufeng \n\n https://t.co/yYIH5haYEI',
#   'source': 'Twitter Web App',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 01:56:03+00:00',
#   'id': 1534353532316315648,
#   'text': 'Frustrating Rant Over. #RaysUp #stressed #baseball',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 01:35:09+00:00',
#   'id': 1534348270058803201,
#   'text': "https://t.co/AHBuwYjcbp\nStressed parents don't worry now. TRY CANADIAN #1 OIL TO RESTORE YOUR BALANCE WITH 20% PROMO CODE: PIN20 WITH ALL SORT OF PRODUCTS.\nhttps://t.co/cVUaWJMOVT\n#stress #Stressed #stressrelief #stressmanagement #mother #Moms #Parents #parentsrights #suffering",
#   'source': 'Twitter for Android',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 01:34:35+00:00',
#   'id': 1534348127314104320,
#   'text': '#RelieveStress #relief #anxiety #anxietyLife #anxietypath #anxietyfighter #stressrelief #stress #stressed #stressmanagement #Healing https://t.co/CsEYDaidIQ\nHERE IS THE CANADIAN #1 OIL! CHECK IT OUT! PROMO Code: PIN20 #CBDオイル\n#CBD #cbdoil #HealthyEating #stressclinic #stressed',
#   'source': 'Twitter for Android',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 01:30:20+00:00',
#   'id': 1534347060316622849,
#   'text': 'Anyone that can help please do, I am feeling financially crushed right about now and this would help buy us more time to get life straightened out. #GoFundMe #family #life #finances #bills #BeKind #stressed \nhttps://t.co/Z4CgGA5vsW',
#   'source': 'Twitter for Android',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-08 00:57:05+00:00',
#   'id': 1534338694060154881,
#   'text': 'How I know I’m #stressed: ate a bowl of cereal, Salt &amp; Vinegar chips, &amp; a coke for dinner. #stresseating https://t.co/2ivzf0XNQo',
#   'source': 'Twitter for iPhone',
#   'name': 'Christine Sipka',
#   'username': 'Freonut',
#   'location': 'Brisbane',
#   'verified': False,
#   'description': 'Family * Gaming * Footy * Uni \nYou are beautiful and can change the world if you first believe in yourself. \n#ForeverFreo',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/552733105266503682/s2R2Nth4_normal.jpeg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': "['None - 204x498 - Alt: None']",
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:12+00:00',
#   'id': 1534792965801005061,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Review: "Under the…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:12+00:00',
#   'id': 1534792964312076288,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Canada House Hunti…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:12+00:00',
#   'id': 1534792962831527937,
#   'text': "#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n It's not Larry Bir…",
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:11+00:00',
#   'id': 1534792961401278464,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Tampa ties Eastern…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:11+00:00',
#   'id': 1534792959740223488,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Denver Broncos cho…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:10+00:00',
#   'id': 1534792958238769152,
#   'text': "#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Tennis tops women'…",
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:10+00:00',
#   'id': 1534792956737204224,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Buck Showalter and…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:10+00:00',
#   'id': 1534792955273302018,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Joe Maddon, Fire D…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:09+00:00',
#   'id': 1534792953784311808,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n After Uvalde, teac…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:09+00:00',
#   'id': 1534792952358264832,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Major South Korean…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:09+00:00',
#   'id': 1534792950500282368,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNhuB\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Car crashes into B…',
#   'source': 'IFTTT',
#   'name': 'TrustedHealth.Info',
#   'username': 'TrustHealthInf',
#   'location': nan,
#   'verified': False,
#   'description': 'Trusted Health Information',
#   'profile_image_url': 'https://pbs.twimg.com/profile_images/1311774667481452544/GgP8UoqB_normal.jpg',
#   'retweets': 0,
#   'likes': 0,
#   'attachments': '[]',
#   'replies': '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'},
#  {'created_at': '2022-06-09 07:02:08+00:00',
#   'id': 1534792949007253505,
#   'text': '#Stressed out?\n\nRead on the #healthy ways to cope with #Stress and a lot more trusted health information.\n\nhttps://t.co/c5M9uLNPk9\n\nFree health information for all. #FreeHealthRevolution\n\nPlease share with your friends.. #Retweet\n\n#domains Freddie Mercury\n\n Politico takes a m…',
#   'source': 'IFTTT',
# ...
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534994158703853584","text":"https://t.co/2BlGnxH73J"}],"meta":{"newest_id":"1534994158703853584","oldest_id":"1534994158703853584","result_count":1}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534988781194989568","text":"@hatreenax Its a case of having to be ok but thank you xxx"},{"id":"1534985494123118594","text":"@pooliechick Aww hope your doing ok ❤️❤️❤️"}],"meta":{"newest_id":"1534988781194989568","oldest_id":"1534985494123118594","result_count":2}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534975692664098816","text":"@halfwaythere_1 @1LUNCarmy If you only have 50 dollars left, I won't invest it in #LUNC ."},{"id":"1534975108594315264","text":"@bwww77 @1LUNCarmy I guess the question should be, would you put $50 into lunc? If the burn rate is as predicted that $50 could turn into $690,000."},{"id":"1534968326719414274","text":"@bwww77 @1LUNCarmy @halfwaythere_1 https://t.co/QwD35Lb15v"},{"id":"1534965159491686400","text":"@1LUNCarmy @halfwaythere_1 #Luna is a very good example. Most people who invested all their money ended up jumping off the building."},{"id":"1534943591801442304","text":"@halfwaythere_1 Never put your last money into #cryptocurrency whether it's #lunc #BTC or anything! Only put in what you can afford! \uD83E\uDD19"}],"meta":{"newest_id":"1534975692664098816","oldest_id":"1534943591801442304","result_count":5}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534828954317688832","text":"@Relaxy_Taxi \uD83D\uDE80 SHIBA MOVE RUN \uD83D\uDE80\n\uD83D\uDD30Spywolf | Pinksale | InterFi Network KYC\n\uD83D\uDD10Spywolf Audit\n✅SC:75 BNB - HC:150 BNB✅\n\uD83D\uDD52Presale: https://t.co/CgjKdEMvhE\n\n07/06 15:00 (UTC) ~ 08/06 15:00 (UTC)\n$SMR: 0xeb48b42331F4C5D4458DD1c077E897dFFcb691b8 \nhttps://t.co/PaZlawg1nu"}],"meta":{"newest_id":"1534828954317688832","oldest_id":"1534828954317688832","result_count":1}}
# {"data":[{"id":"1534829600357982208","text":"@Relaxy_Taxi \uD83D\uDE80 SHIBA MOVE RUN \uD83D\uDE80\n\uD83D\uDD30Spywolf | Pinksale | InterFi Network KYC\n\uD83D\uDD10Spywolf Audit\n✅SC:75 BNB - HC:150 BNB✅\n\uD83D\uDD52Presale: https://t.co/CgjKdEMvhE\n\n07/06 15:00 (UTC) ~ 08/06 15:00 (UTC)\n$SMR: 0xeb48b42331F4C5D4458DD1c077E897dFFcb691b8 \nhttps://t.co/PaZlawg1nu"}],"meta":{"newest_id":"1534829600357982208","oldest_id":"1534829600357982208","result_count":1}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534905067068964865","text":"@ScottyWantsToNo @FortniteGame Yeah its really hard to vibe when you're getting constant pop ups every time you boot up the game going through your entire friend list. #vibekiller"}],"meta":{"newest_id":"1534905067068964865","oldest_id":"1534905067068964865","result_count":1}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534632757787144192","text":"@pianotm26 Thank you, Thomas!"},{"id":"1534626077519319043","text":"@schiekapedia Wishing you all the best in your journey down the highway!"},{"id":"1534618421484146689","text":"@DonCardenasArt Thanks very much!"},{"id":"1534614806661107712","text":"@schiekapedia Take care and good luck!"},{"id":"1534614321451347968","text":"@LazyHorde Thank you!"},{"id":"1534612465937522688","text":"@schiekapedia Good luck!!"}],"meta":{"newest_id":"1534632757787144192","oldest_id":"1534612465937522688","result_count":6}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534948442795122688","text":"@iamserenataylor @Mattytargett Ahhh fairs.  I meant it in  a positive way suggesting maybe your team had grown or some stuff had been updated to help you kind of thing.  Maybe just the other departments are now a tad more professional lol."},{"id":"1534936798958346240","text":"@deezamc79 @Mattytargett And it got delayed…  I could’ve had at least 2 more minutes with 4 more backdrops… \uD83E\uDD23\uD83E\uDD23"},{"id":"1534936580296679425","text":"@cjlow_ @Mattytargett It doesn’t take so long for the media side to be done and never has. It’s not held up by media related duties. Our department and everyone in it have always been professional and we are not doing anything we never already did before. Just saying. \uD83D\uDE0A"},{"id":"1534876086798102528","text":"@iamserenataylor @Mattytargett You have just photo shopped Targett over Dan Ashworth \uD83D\uDE2D\uD83D\uDE2D\uD83D\uDE02"},{"id":"1534838650852233223","text":"@iamserenataylor @MitchT1998 @Mattytargett Great work Serena ...keep it up plenty more to do this summer I reckon"},{"id":"1534824881904402432","text":"@iamserenataylor @Mattytargett Loving your work! Great gig?"},{"id":"1534801316073062400","text":"@iamserenataylor @Mattytargett I love MT because he's so understated - exactly the type of personality that we should be bringing to the club as we move into phase two of the project."},{"id":"1534669046351859714","text":"@manxpie86 @iamserenataylor @Mattytargett Twats dressed like twas and Matt Targett"},{"id":"1534652296126427136","text":"@iamserenataylor @Mattytargett well done :)"},{"id":"1534652179604197377","text":"@iamserenataylor @Mattytargett #NUFC https://t.co/oPimcb48aG"}],"meta":{"newest_id":"1534948442795122688","oldest_id":"1534652179604197377","result_count":10,"next_token":"b26v89c19zqg8o3fpyzm99lsuxty0to485ag85abg34vx"}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1534567001988939782","text":"@STLStylings Next week"},{"id":"1534566719137660934","text":"@AQualityMess I just saw your TikTok! When is yours? Mines is Saturday"},{"id":"1534566585586827264","text":"@STLStylings Whew girl same"}],"meta":{"newest_id":"1534567001988939782","oldest_id":"1534566585586827264","result_count":3}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"data":[{"id":"1536784514608922624","text":"@N1181xX Yep, the excitement has been replaced with anxiety &amp; feeling frightened that we’ll be homeless! We are in a similar situation where the house is there, we have been inside it &amp; looked round, yet it still won’t get signed off \uD83D\uDE33 It’s so disheartening \uD83E\uDD7A"},{"id":"1536740826193207296","text":"@jenstimp That’s nearly a year!! So sorry to hear this, it must have ruined any excitement completely for you all. Site we were looking at is in Farnham. From what I can see all the houses are ready but the road doesn’t seem to be finished"},{"id":"1536709197248745472","text":"@N1181xX Where abouts are you looking? They’ve said that the delays are lack of builders &amp; materials, which is ridiculous as they have continued to build other houses on the site! I was meant to move August 2021 &amp; am still waiting, with no move date in sight!"},{"id":"1536684479720443907","text":"@jenstimp Someone else in the same boat as you on trustpilot plus others. Have they told you what the delay is? Phase 1 of where I’m looking was sold out January or before I think, but nobody has moved in yet and the phase 2 launch has been pushed back. Houses are all complete too."},{"id":"1536616143942733825","text":"@N1181xX What did you see on Trustpilot? I’m just exhausted from it all &amp; communication is shockingly bad! They tried to offer me £500 in compensation, which doesn’t go anywhere near the cost to cover a months rent ffs!!! If I had any choice, I’d go elsewhere!"},{"id":"1536599528752701440","text":"@jenstimp Oh my gosh! So sorry to hear all that, shocking! I really hope you and the kids get something sorted either way. I read some reviews on trustpilot which concerned me now this."},{"id":"1536520173955473411","text":"@N1181xX This is in Basingstoke! Just had the terrible news that Premier (the warranty company) have walked away, so no warranty sign off! I’m almost out of money for my temporary rental, that I was meant to be in for 2 months, now over 6! My kids &amp; I are almost homeless now!"},{"id":"1536433360624558081","text":"@jenstimp Oh no, we’ve been looking at an Aster home. Which development is this if you don’t mind me asking?"},{"id":"1534577044276879362","text":"@AsterGroupUK I’m in talks with team members &amp; now on level 2 of my complaints! People need to know how long they could be delayed, so they don’t end up severely out of pocket, almost homeless, stressed beyond belief &amp; living in limbo for a year or more!"},{"id":"1534567076408459265","text":"@jenstimp Hi Jen - sorry to hear this.  We understand our sales team are in communication about this but please drop us a DM if you’d like a member of the sales team to contact you."}],"meta":{"newest_id":"1536784514608922624","oldest_id":"1534567076408459265","result_count":10}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}
# {"meta":{"result_count":0}}

# %%
#display(unprocesed_list)
dataFrame=pd.DataFrame(unprocesed_list)
# display(dataFrame)
new_no_replies = dataFrame[dataFrame['replies'].isin(['{"meta":{"result_count":0}}'])]
with_replies = ~ dataFrame['replies'].isin(['{"meta":{"result_count":0}}'])
pure_replies = ~ dataFrame['replies'].isin(['{"meta":{"result_count":0}}', '{"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}'])
from_many_replies_reretrived = dataFrame[pure_replies]

# %%
from_many_replies_reretrived.to_csv(r'from_many_replies_reretrived.csv',index = False, header=True)

# %%
merged_tweet_with_replies = pd.concat([clean_replies_df, from_many_replies_reretrived])
display(merged_tweet_with_replies)
merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only.csv',index = False, header=True)
# Out:
#                     created_at                   id  \
# 0    2022-06-13 22:56:56+00:00  1536482781139705857
# 9    2022-06-13 18:47:52+00:00  1536420101230141446
# 23   2022-06-13 15:33:42+00:00  1536371239723360257
# 24   2022-06-13 15:17:14+00:00  1536367096954621954
# 26   2022-06-13 14:21:47+00:00  1536353140173324291
# ..                         ...                  ...
# 567  2022-06-08 21:30:16+00:00  1534649032420868099
# 572  2022-06-08 18:19:41+00:00  1534601071359688704
# 575  2022-06-08 16:06:10+00:00  1534567469649743876
# 577  2022-06-08 15:58:12+00:00  1534565466416480256
# 584  2022-06-08 13:54:01+00:00  1534534213021614085
#
#                                                   text               source  \
# 0                           good night im #stressed xx   Twitter for iPhone
# 9    I have another flight tomorrow.. would you hel...  Twitter for Android
# 23   This life has really beaten me down and now I'...  Twitter for Android
# 24     Home alone and I can’t find my 🌹! #Stressed 😂😂😂   Twitter for iPhone
# 26   🚨Hoping for a good day. I've got so much that ...  Twitter for Android
# ..                                                 ...                  ...
# 567  @FortniteGame please fix this “friend request ...   Twitter for iPhone
# 572  More than a little delirious today. My last da...   Twitter for iPhone
# 575  When you literally get 11 minutes from the tim...   Twitter for iPhone
# 577  Getting ready for thin vendor event just remin...   Twitter for iPhone
# 584  Look at that, a year ago today since I paid my...   Twitter for iPhone
#
#                        name      username  \
# 0    ‎ً ★ mar’s fiancé ?! 2  tobesocharly
# 9    ‎ً ★ mar’s fiancé ?! 2  tobesocharly
# 23   ‎ً ★ mar’s fiancé ?! 2  tobesocharly
# 24   ‎ً ★ mar’s fiancé ?! 2  tobesocharly
# 26   ‎ً ★ mar’s fiancé ?! 2  tobesocharly
# ..                      ...           ...
# 567         Christine Sipka       Freonut
# 572         Christine Sipka       Freonut
# 575         Christine Sipka       Freonut
# 577         Christine Sipka       Freonut
# 584         Christine Sipka       Freonut
#
#                                               location  verified  \
# 0    my policeman enthusiast     ⌗1 Nana’s House st...     False
# 9    my policeman enthusiast     ⌗1 Nana’s House st...     False
# 23   my policeman enthusiast     ⌗1 Nana’s House st...     False
# 24   my policeman enthusiast     ⌗1 Nana’s House st...     False
# 26   my policeman enthusiast     ⌗1 Nana’s House st...     False
# ..                                                 ...       ...
# 567                                           Brisbane     False
# 572                                           Brisbane     False
# 575                                           Brisbane     False
# 577                                           Brisbane     False
# 584                                           Brisbane     False
#
#                                            description  \
# 0    ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 9    ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 23   ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 24   ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# 26   ⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRP...
# ..                                                 ...
# 567  Family * Gaming * Footy * Uni \nYou are beauti...
# 572  Family * Gaming * Footy * Uni \nYou are beauti...
# 575  Family * Gaming * Footy * Uni \nYou are beauti...
# 577  Family * Gaming * Footy * Uni \nYou are beauti...
# 584  Family * Gaming * Footy * Uni \nYou are beauti...
#
#                                      profile_image_url  retweets  likes  \
# 0    https://pbs.twimg.com/profile_images/153374527...         0      0
# 9    https://pbs.twimg.com/profile_images/153374527...         0      9
# 23   https://pbs.twimg.com/profile_images/153374527...         0      3
# 24   https://pbs.twimg.com/profile_images/153374527...         0      0
# 26   https://pbs.twimg.com/profile_images/153374527...         1      0
# ..                                                 ...       ...    ...
# 567  https://pbs.twimg.com/profile_images/552733105...         0      5
# 572  https://pbs.twimg.com/profile_images/552733105...         2     13
# 575  https://pbs.twimg.com/profile_images/552733105...        52   2036
# 577  https://pbs.twimg.com/profile_images/552733105...         0      2
# 584  https://pbs.twimg.com/profile_images/552733105...         0      0
#
#                                            attachments  \
# 0                                                   []
# 9    ['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro....
# 23                                                  []
# 24                                                  []
# 26                                                  []
# ..                                                 ...
# 567                                                 []
# 572                                                 []
# 575  ['https://pbs.twimg.com/media/FUvg-iCWUAAxnfy....
# 577                                                 []
# 584  ['https://pbs.twimg.com/media/FUvCu7MWIAITPNa....
#
#                                                replies
# 0    {"data":[{"id":"1536487441468727297","text":"@...
# 9    {"data":[{"id":"1536483956304093185","text":"@...
# 23   {"data":[{"id":"1536407609988849672","text":"@...
# 24   {"data":[{"id":"1536369878608842753","text":"@...
# 26   {"data":[{"id":"1536353141624655873","text":"I...
# ..                                                 ...
# 567  {"data":[{"id":"1534905067068964865","text":"@...
# 572  {"data":[{"id":"1534632757787144192","text":"@...
# 575  {"data":[{"id":"1534948442795122688","text":"@...
# 577  {"data":[{"id":"1534567001988939782","text":"@...
# 584  {"data":[{"id":"1536784514608922624","text":"@...
#
# [148 rows x 14 columns]

# %% [markdown]
# DATA  : FROM
# start_time = "2022-06-09T00:00:00Z"
# end_time = "2022-06-15T00:00:00Z"
