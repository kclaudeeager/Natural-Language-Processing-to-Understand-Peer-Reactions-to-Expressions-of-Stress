# %%
import csv
# import the pandas library
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# merged_tweet_with_replies = pd.concat([clean_replies_df, from_many_replies_reretrived])
previous_analyzedData=pd.read_csv("data/cleaned_tweet_with_replies_only.csv")
print(previous_analyzedData.shape)
latest_analyzedData=pd.read_csv("data/procesed_23_06.csv")
print(latest_analyzedData.shape)
# merged_tweet_with_replies = pd.concat([clean_replies_df, dataFrame])
merged_tweet_with_replies = pd.concat([previous_analyzedData, latest_analyzedData])
#print("df1:"+str(len(previous_analyzedData)+"\n df2:"+str(len(latest_analyzedData)+"\n df3:"+str(len(merged_tweet_with_replies)))
# print(len(previous_analyzedData))
# print(len((latest_analyzedData))
print(merged_tweet_with_replies.shape)
display(merged_tweet_with_replies)
merged_tweet_with_replies=merged_tweet_with_replies.drop_duplicates()
print(merged_tweet_with_replies.shape)
display(merged_tweet_with_replies)
#merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only.csv',index = False, header=True)
merged_tweet_with_replies.to_csv(r'data/merged_tweet_with_replies.csv',index = False, header=True)
# Out:
# (148, 14)
# (46, 14)
# (194, 14)
#                    created_at                   id  \
# 0   2022-06-13 22:56:56+00:00  1536482781139705857
# 1   2022-06-13 18:47:52+00:00  1536420101230141446
# 2   2022-06-13 15:33:42+00:00  1536371239723360257
# 3   2022-06-13 15:17:14+00:00  1536367096954621954
# 4   2022-06-13 14:21:47+00:00  1536353140173324291
# ..                        ...                  ...
# 41  2022-06-16 16:31:06+00:00  1537472849811755011
# 42  2022-06-16 13:27:27+00:00  1537426632738234368
# 43  2022-06-16 12:31:38+00:00  1537412582214180865
# 44  2022-06-16 13:27:27+00:00  1537426632738234368
# 45  2022-06-16 13:27:27+00:00  1537426632738234368
#
#                                                  text               source  \
# 0                          good night im #stressed xx   Twitter for iPhone
# 1   I have another flight tomorrow.. would you hel...  Twitter for Android
# 2   This life has really beaten me down and now I'...  Twitter for Android
# ...

# %%
#Function that renders the tweet list from csv
def getTweetList(jsonFile):
    tweetList=list()
    with open(jsonFile,encoding="UTF-8") as tweetData:
        print(tweetData)
        tweetList=json.load(tweetData)
    print(len(tweetList))
    return tweetList

# %%
# tweetRepliesData=pd.read_csv('TweetExtraction\cleaned_tweet_with_replies_only.csv')
tweetList=list()
with open("data\merged_tweet_with_replies.json",encoding="UTF-8") as tweetData:
    print(tweetData)
    tweetList=json.load(tweetData)
print(len(tweetList))
# Out:
# <_io.TextIOWrapper name='data\\merged_tweet_with_replies.json' mode='r' encoding='UTF-8'>
# 130

# %%
 print(tweetList)
# Out:
# [{'created_at': '2022-06-13 22:56:56+00:00', 'id': '1536482781139705857', 'text': 'good night im #stressed xx', 'source': 'Twitter for iPhone', 'name': '\u200eً ★ mar’s fiancé ?! 2', 'username': 'tobesocharly', 'location': 'my policeman enthusiast     ⌗1 Nana’s House stan !!\n   💿 TRACK 1 & 11 OWNER ¿??\nzZz married to kiwi intro          … home = louist91', 'verified': False, 'description': '⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRPSDk1z 🚬 She They', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1533745277898727427/V_3Zh2Lw_normal.jpg', 'retweets': 0, 'likes': 0, 'attachments': '[]', 'replies': '{"data":[{"id":"1536487441468727297","text":"@tobesocharly goodnightt"},{"id":"1536484151418830849","text":"@tobesocharly goodnight, sleep well and see you in a few hours&lt;3"},{"id":"1536483010605989888","text":"@sweetdayIight cries yes i will &lt;33"},{"id":"1536482927286095878","text":"@sweetdayIight i love you too sleep well mwahh"},{"id":"1536482868435771396","text":"
# ...

# %%
#Return list of tweet replies
def render_reply_list(tweet):
    replies=tweet['replies']
    # data=replies['data']
    #res = json.loads(replies)
    # print(type(res))
    # print(res['data'])
    return replies

# %%
def render_only_tweet_texts(tweetList):
    tweetTexts=[tweet['text'] for tweet in tweetList]
        
    return tweetTexts

# %%
tweetTexts=render_only_tweet_texts(tweetList)
display(tweetTexts)
# Out:
# ['good night im #stressed xx',
#  'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw',
#  "This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone",
#  'Home alone and I can’t find my 🌹! #Stressed 😂😂😂',
#  "🚨Hoping for a good day. I've got so much that needs to get done but can't do it without some help. My life is mostly unbearable and I need help. Please help me. Goal200\n\n#help #stressed #hope #Donation\n\nhttps://t.co/l9nqZldVpl\nVenmo: Dennis-M-3 \nPaypal:dennishrh88@gmail.com",
# ...

# %%
import requests
#map each tweet replies with its corresponding classification
def classify_tweet_replies(replies):
    reply_with_sentiment_analyzis_list=list()
    
    for reply in replies:
        url = "http://localhost/predict-review?review="+reply['text']

        payload = ""
        headers = {}
        
        response = requests.request("GET", url, headers=headers, data=payload)
        reply_with_sentiment_dict={"id":reply['id'],"reply":reply['text'],"classification":response.text}
        reply_with_sentiment_analyzis_list.append(reply_with_sentiment_dict)
        
    #     print(reply['text'])
    #     print(response.text) print("*"*50)
    
    #print(reply_with_sentiment_analyzis_list)
    #print("*"*50)
    return reply_with_sentiment_analyzis_list

# %% [markdown]
# # Rearranging the tweet replies accordind to their positivity
# ##The following function will take all tweets and rearrange the replies

# %%
def rearrange_tweet_replies(tweetList):
    for tweet in tweetList:
        replies=tweet['replies']
        res=json.loads(replies)
        only_replies_texts=res['data']
        reply_list=classify_tweet_replies(only_replies_texts)
        postive_replies=[rep for rep in reply_list if (json.loads(rep.get('classification'))).get('prediction')=='Positive']
        negative_replies=[rep for rep in reply_list if (json.loads(rep.get('classification'))).get('prediction')=='Negative']
        neutral_replies=[rep for rep in reply_list if (json.loads(rep.get('classification'))).get('prediction')=='Neutral']
        postive_replies=sorted(postive_replies,key=lambda x:x.get('classification'),reverse=True)
        negative_replies=sorted(negative_replies,key=lambda x:x.get('classification'),reverse=False)
        neutral_replies=sorted(neutral_replies,key=lambda x:x.get('classification'),reverse=True)
        reply_list=postive_replies+neutral_replies+negative_replies
        tweet['replies']=reply_list
        print(reply_list,'\n')
        print(tweet)
        
#         print("Postives sorted: ",postive_replies)
#         print("Postives: ",postive_replies)
#         print("Neutrals: ",neutral_replies)
#         print("Negatives: ",negative_replies)
    print(tweetList)

# %%
rearrange_tweet_replies(tweetList)
print(tweetList)
# Out:
# [{'id': '1536483010605989888', 'reply': '@sweetdayIight cries yes i will &lt;33', 'classification': '{"prediction":"Positive","Probability":"0.39"}'}, {'id': '1536487441468727297', 'reply': '@tobesocharly goodnightt', 'classification': '{"prediction":"Positive","Probability":"0.34"}'}, {'id': '1536484151418830849', 'reply': '@tobesocharly goodnight, sleep well and see you in a few hours&lt;3', 'classification': '{"prediction":"Positive","Probability":"0.27"}'}, {'id': '1536482833442775042', 'reply': '@tobesocharly goodnight i love you', 'classification': '{"prediction":"Positive","Probability":"0.03"}'}, {'id': '1536482927286095878', 'reply': '@sweetdayIight i love you too sleep well mwahh', 'classification': '{"prediction":"Positive","Probability":"0.02"}'}, {'id': '1536482868435771396', 'reply': '@tobesocharly if u need to talk about it text me &lt;3', 'classification': '{"prediction":"Neutral","Probability":"0.13"}'}]
#
# ...

# %%
print(type(tweetList))
print(tweetList[1]['replies'])
# Out:
# <class 'list'>
# [{'id': '1536483956304093185', 'reply': '@ChomperKat Sure. Just tell me what I can do 😌', 'classification': '{"prediction":"Positive","Probability":"0.37"}'}, {'id': '1536420468424691712', 'reply': '@ChomperKat Sure! :)', 'classification': '{"prediction":"Positive","Probability":"0.34"}'}]

# %%
print(render_reply_list(tweetList[1]))
# Out:
# [{'id': '1536483956304093185', 'reply': '@ChomperKat Sure. Just tell me what I can do 😌', 'classification': '{"prediction":"Positive","Probability":"0.37"}'}, {'id': '1536420468424691712', 'reply': '@ChomperKat Sure! :)', 'classification': '{"prediction":"Positive","Probability":"0.34"}'}]

# %%
# new_tweet_dictionary_list=list(dict())
# for tweet in tweetList:
    
#    classification=classify_tweet_replies(render_reply_list(tweet))
#    new_tweet_dictionary_list.append({"tweet":tweet['text'],"attachement":tweet['attachments'],"analysis":classification})
# print(new_tweet_dictionary_list)
# json.dump(new_tweet_dictionary_list)   
print(type(tweetList))
# Out:
# <class 'list'>

# %%
# convert into json
# final_data = json.dumps(new_tweet_dictionary_list, indent=2)
# print(final_data)
final_data = json.dumps(tweetList, indent=2)
print(final_data)
new_tweet_dictionary_list=tweetList
# Out:
# [
#   {
#     "created_at": "2022-06-13 22:56:56+00:00",
#     "id": "1536482781139705857",
#     "text": "good night im #stressed xx",
#     "source": "Twitter for iPhone",
#     "name": "\u200e\u064b \u2605 mar\u2019s fianc\u00e9 ?! 2",
#     "username": "tobesocharly",
#     "location": "my policeman enthusiast     \u23171 Nana\u2019s House stan !!\n   \ud83d\udcbf TRACK 1 & 11 OWNER \u00bf??\nzZz married to kiwi intro          \u2026 home = louist91",
#     "verified": false,
#     "description": "\u2800\u2800 \u2800 \u2800. . . vic de angelis\u2019 https://t.co/0jVRPSDk1z \ud83d\udeac She They",
#     "profile_image_url": "https://pbs.twimg.com/profile_images/1533745277898727427/V_3Zh2Lw_normal.jpg",
#     "retweets": 0,
#     "likes": 0,
#     "attachments": "[]",
#     "replies": [
#       {
#         "id": "1536483010605989888",
#         "reply": "@sweetdayIight cries yes i will &lt;33",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.39\"}"
# ...

# %%
print(new_tweet_dictionary_list)
# Out:
# [{'tweet': 'good night im #stressed xx', 'attachement': '[]', 'analysis': [{'reply': '@tobesocharly goodnightt', 'classification': '{"prediction":"Positive","Probability":"0.34"}'}, {'reply': '@tobesocharly goodnight, sleep well and see you in a few hours&lt;3', 'classification': '{"prediction":"Positive","Probability":"0.27"}'}, {'reply': '@sweetdayIight cries yes i will &lt;33', 'classification': '{"prediction":"Positive","Probability":"0.39"}'}, {'reply': '@sweetdayIight i love you too sleep well mwahh', 'classification': '{"prediction":"Positive","Probability":"0.02"}'}, {'reply': '@tobesocharly if u need to talk about it text me &lt;3', 'classification': '{"prediction":"Neutral","Probability":"0.13"}'}, {'reply': '@tobesocharly goodnight i love you', 'classification': '{"prediction":"Positive","Probability":"0.03"}'}]}, {'tweet': 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', 'at
# ...

# %%
# convert into json
# file name is mydata
# print(type(final_data))
# with open("data/my_analyzed_data.json", "w") as jsonFile:
#    json.dump(new_tweet_dictionary_list,jsonFile)
    
# print(type(final_data))
# with open("data/my_analyzed_data_24_06.json", "w") as jsonFile:
#    json.dump(new_tweet_dictionary_list,jsonFile)
    
    
print(type(final_data))
with open("data/my_analyzed_data_25_06.json", "w") as jsonFile:
   json.dump(new_tweet_dictionary_list,jsonFile)
# Out:
# <class 'str'>

# %%
# with open('data/my_analyzed_data.json', encoding='utf-8-sig') as f_input:
#     df = pd.read_json(f_input)

# df.to_csv('data/my_analyzed_data.csv', encoding='utf-8', index=False)
# with open('data/my_analyzed_data_24_06.json', encoding='utf-8-sig') as f_input:
#     df = pd.read_json(f_input)

#     df.to_csv('data/my_analyzed_data_24_06.csv', encoding='utf-8', index=False)
with open('data/my_analyzed_data_25_06.json', encoding='utf-8-sig') as f_input:
    df = pd.read_json(f_input)

    df.to_csv('data/my_analyzed_data_25_06.csv', encoding='utf-8', index=False)

# %%
#data visualization for distribution
def mapReplyWithItsClass(tweetList):
    repliesWithClassList=list()
#     for tweet in tweetList:
        
#         analysis=tweet['analysis']
#         for each_reply_analyzis in analysis:
#             reply=each_reply_analyzis['reply']
#             reply_class=each_reply_analyzis['classification']
#             #print(type(reply_class))
#             reply_class = json.loads(reply_class)
#            # print(reply_class['prediction'])
#             reply_with_class_dict={"reply":reply,"group":reply_class['prediction']}
#             repliesWithClassList.append(reply_with_class_dict)
    for tweet in tweetList:
        analysis=tweet['replies']
        for each_reply_analyzis in analysis:
            reply=each_reply_analyzis['reply']
            reply_class=each_reply_analyzis['classification']
            #print(type(reply_class))
            reply_class = json.loads(reply_class)
           # print(reply_class['prediction'])
            reply_with_class_dict={"reply":reply,"group":reply_class['prediction']}
            repliesWithClassList.append(reply_with_class_dict)
            
            
        
        
    print(repliesWithClassList)
            
    return repliesWithClassList

# %%
#print(new_tweet_dictionary_list)
repliesWithClassList=mapReplyWithItsClass(new_tweet_dictionary_list)
# Out:
# [{'reply': '@sweetdayIight cries yes i will &lt;33', 'group': 'Positive'}, {'reply': '@tobesocharly goodnightt', 'group': 'Positive'}, {'reply': '@tobesocharly goodnight, sleep well and see you in a few hours&lt;3', 'group': 'Positive'}, {'reply': '@tobesocharly goodnight i love you', 'group': 'Positive'}, {'reply': '@sweetdayIight i love you too sleep well mwahh', 'group': 'Positive'}, {'reply': '@tobesocharly if u need to talk about it text me &lt;3', 'group': 'Neutral'}, {'reply': '@ChomperKat Sure. Just tell me what I can do 😌', 'group': 'Positive'}, {'reply': '@ChomperKat Sure! :)', 'group': 'Positive'}, {'reply': '@myfiVeApp Thank you ❤️', 'group': 'Positive'}, {'reply': "@WorkerUnityNow You're not alone! We don't want you to feel that way. We made an app that allows you to find the top 5 people most like you wherever you go and we'd love for you to join our community!\n\nDM with any Q's!\n\nIOS:  https://t.co/DM2bXJh0DV\n\nAndroid: https://t.co/86MylpD88F", 'group': 'Positive'
# ...

# %%
(pd.DataFrame(repliesWithClassList)).to_csv(r'data/tweet_replies_distribution_24_06.csv',index = False, header=True)

# %%
# with open("data/tweet_replies_distribution.json", "w") as jsonFile:
#    json.dump(repliesWithClassList,jsonFile)
with open("data/tweet_replies_distribution_24_06.json", "w") as jsonFile:
   json.dump(repliesWithClassList,jsonFile)

# %%
# # warnings.filterwarnings("ignore")
# # # seeding
# # np.random.seed(123)
# import pandas as pd
# data = pd.read_csv('data/tweet_replies_distribution.csv')
# categories = ['Positive','Neutral','Negative']
# # data.head()
# # len(data)
# data.isnull().any().any()
# data.isnull().any()
# data = data.dropna(subset=['reply','group'])
# # data['clean_text','category'].isnull().sum()
# # data.isnull().any().any()
# # data.isnull().any()
# data.isnull().any()
# warnings.filterwarnings("ignore")
# # seeding
# np.random.seed(123)
import pandas as pd
data = pd.read_csv('data/tweet_replies_distribution_24_06.csv')
categories = ['Positive','Neutral','Negative']
# data.head()
# len(data)
data=data.drop_duplicates()
data.to_csv(r'data/tweet_replies_distribution_24_06_no_duplicates.csv',index = False, header=True)
print(data.shape)
data.isnull().any().any()
data.isnull().any()
data = data.dropna(subset=['reply','group'])
# data['clean_text','category'].isnull().sum()
# data.isnull().any().any()
# data.isnull().any()
data.isnull().any()
# Out:
# (177, 2)
# reply    False
# group    False
# dtype: bool

# %%
def visualize():
    category_count = data.groupby('group').count()
    plt.bar(category_count.index.values, category_count["reply"])
    plt.xticks(rotation='vertical')
    plt.xlabel('Sentiment Categories')
    plt.ylabel('Number of replies')
    plt.show()
    return category_count
visualize()
# Out:
#           reply
# group
# Negative     19
# Neutral      23
# Positive    135

# %% [markdown]
# def visualize():
#     category_count = data.groupby('group').count()
#     plt.bar(category_count.index.values, category_count["reply"])
#     plt.xticks(rotation='vertical')
#     plt.xlabel('Sentiment Categories')
#     plt.ylabel('Number of replies')
#     plt.show()
#     return category_count
# visualize()

# %%
print(mapReplyWithItsClass(new_tweet_dictionary_list))
# Out:
# [{'reply': '@tobesocharly goodnightt', 'group': 'Positive'}, {'reply': '@tobesocharly goodnight, sleep well and see you in a few hours&lt;3', 'group': 'Positive'}, {'reply': '@sweetdayIight cries yes i will &lt;33', 'group': 'Positive'}, {'reply': '@sweetdayIight i love you too sleep well mwahh', 'group': 'Positive'}, {'reply': '@tobesocharly if u need to talk about it text me &lt;3', 'group': 'Neutral'}, {'reply': '@tobesocharly goodnight i love you', 'group': 'Positive'}, {'reply': '@ChomperKat Sure. Just tell me what I can do 😌', 'group': 'Positive'}, {'reply': '@ChomperKat Sure! :)', 'group': 'Positive'}, {'reply': '@WorkerUnityNow You are so welcome! Literally!  :)', 'group': 'Positive'}, {'reply': '@myfiVeApp Thank you ❤️', 'group': 'Positive'}, {'reply': "@WorkerUnityNow You're not alone! We don't want you to feel that way. We made an app that allows you to find the top 5 people most like you wherever you go and we'd love for you to join our community!\n\nDM with any Q's!\n\nI
# ...

# %%
import time
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# # create TF-IDF and cosine simillaralities between tweets
#
# from sklearn.metrics.pairwise import cosine_similarity
#
#
# # Initialize an instance of tf-idf Vectorizer
# tfidf_vectorizer = TfidfVectorizer()
#
# # Generate the tf-idf vectors for the corpus
# tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)
#
# # compute and print the cosine similarity matrix
# cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
# print(cosine_sim)

# %%
def cosineSimillarity(corpus):
    
    start = time.time()
    # Initialize an instance of tf-idf Vectorizer
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # Generate the tf-idf vectors for the corpus
    tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)

    # compute and print the cosine similarity matrix
    #cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    #print(cosine_sim)
    # Print time taken
    print("Time taken: %s seconds" % (time.time() - start))
    return cosine_sim

# %%
corpus = ['The sun is the largest celestial body in the solar system', 
          'The solar system consists of the sun and eight revolving planets', 
          'Ra was the Egyptian Sun God', 
          'The Pyramids were the pinnacle of Egyptian architecture', 
          'The quick brown fox jumps over the lazy dog']
cosineSimillarity(corpus)
# Out:
# Time taken: 0.0055620670318603516 seconds
# array([[1.        , 0.2681909 , 0.12582678, 0.        , 0.        ],
#        [0.2681909 , 1.        , 0.12582678, 0.        , 0.        ],
#        [0.12582678, 0.12582678, 1.        , 0.19350098, 0.        ],
#        [0.        , 0.        , 0.19350098, 1.        , 0.        ],
#        [0.        , 0.        , 0.        , 0.        , 1.        ]])

# %%
# # merged_tweet_with_replies = pd.concat([clean_replies_df, from_many_replies_reretrived])
# previous_analyzedData=pd.read_csv("data/my_analyzed_data.csv")
# latest_analyzedData=pd.read_csv("data/procesed_23_06.csv")
# #display(previous_clean_replies)
# # merged_tweet_with_replies = pd.concat([clean_replies_df, dataFrame])
# merged_tweet_with_replies = pd.concat([previous_analyzedData, latest_analyzedData])
# display(merged_tweet_with_replies)
# # merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only.csv',index = False, header=True)
# merged_tweet_with_replies.to_csv(r'cleaned_tweet_with_replies_only_23_06.csv',index = False, header=True)
# Out:
#                                                 tweet  \
# 0                          good night im #stressed xx
# 1   I have another flight tomorrow.. would you hel...
# 2   This life has really beaten me down and now I'...
# 3     Home alone and I can’t find my 🌹! #Stressed 😂😂😂
# 4   🚨Hoping for a good day. I've got so much that ...
# ..                                                ...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                           attachement  \
# 0                                                  []
# 1   ['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro....
# 2                                                  []
# 3                                                  []
# ...

# %%
# metadata = pd.read_csv('data/my_analyzed_data.csv').dropna()
# metadata.head(148)
metadata = pd.read_csv('data/my_analyzed_data_24_06.csv').dropna()
#metadata=metadata.drop_duplicates()
metadata.head(len(metadata))
# Out:
#                                                  tweet  \
# 0                           good night im #stressed xx
# 1    I have another flight tomorrow.. would you hel...
# 2    This life has really beaten me down and now I'...
# 3      Home alone and I can’t find my 🌹! #Stressed 😂😂😂
# 4    🚨Hoping for a good day. I've got so much that ...
# ..                                                 ...
# 125  @premierinn We are experiencing severe stress ...
# 126  Welp. Yesterday was stressful at work. Looks l...
# 127  I hate the fact that I’m that anxious all the ...
# 128  Welp. Yesterday was stressful at work. Looks l...
# 129  Welp. Yesterday was stressful at work. Looks l...
#
#                                            attachement  \
# 0                                                   []
# 1    ['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro....
# 2                                                   []
# 3                                                   []
# ...

# %%
tweetTextss=metadata['tweet']
print(tweetTextss)
# Out:
# 0                             good night im #stressed xx
# 1      I have another flight tomorrow.. would you hel...
# 2      This life has really beaten me down and now I'...
# 3        Home alone and I can’t find my 🌹! #Stressed 😂😂😂
# 4      🚨Hoping for a good day. I've got so much that ...
#                              ...
# 125    @premierinn We are experiencing severe stress ...
# 126    Welp. Yesterday was stressful at work. Looks l...
# 127    I hate the fact that I’m that anxious all the ...
# 128    Welp. Yesterday was stressful at work. Looks l...
# 129    Welp. Yesterday was stressful at work. Looks l...
# Name: tweet, Length: 130, dtype: object

# %%
corpus=tweetTexts
print(corpus)
# Out:
# ['good night im #stressed xx', 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', "This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone", 'Home alone and I can’t find my 🌹! #Stressed 😂😂😂', "🚨Hoping for a good day. I've got so much that needs to get done but can't do it without some help. My life is mostly unbearable and I need help. Please help me. Goal200\n\n#help #stressed #hope #Donation\n\nhttps://t.co/l9nqZldVpl\nVenmo: Dennis-M-3 \nPaypal:dennishrh88@gmail.com", '"I was under pressure" is not an excuse for toxic #behavior. \n\nBeing #stressed doesn\'t justify #hostility.\nIt\'s not your #Responsibility to absorb their pain. \n\nBeing busy doesn\'t license incivility.\nNo one\'s calendar is too 
# ...

# %%
print(metadata.shape)
print(len(corpus))
cosine_sim=cosineSimillarity(corpus)
print(cosine_sim)
print(cosine_sim.shape)
print((cosine_sim[0]))
# Out:
# (130, 3)
# 130
# Time taken: 0.015984773635864258 seconds
# [[1.         0.00806075 0.00586794 ... 0.00855105 0.0072805  0.0072805 ]
#  [0.00806075 1.         0.04684413 ... 0.00521429 0.00443953 0.00443953]
#  [0.00586794 0.04684413 1.         ... 0.09752583 0.00323182 0.00323182]
#  ...
#  [0.00855105 0.00521429 0.09752583 ... 1.         0.00470957 0.00470957]
#  [0.0072805  0.00443953 0.00323182 ... 0.00470957 1.         1.        ]
#  [0.0072805  0.00443953 0.00323182 ... 0.00470957 1.         1.        ]]
# (130, 130)
# [1.         0.00806075 0.00586794 0.03177628 0.07981698 0.00528789
#  0.1897841  0.00544775 0.1207045  0.0071724  0.01563093 0.00531981
#  0.01031074 0.00709556 0.00772445 0.00518707 0.00536713 0.00695494
#  1.         0.00806075 0.00586794 0.03177628 0.07981698 0.00528789
#  0.1897841  0.00544775 0.1207045  0.0071724  0.01563093 0.00531981
#  0.01031074 0.00709556 0.00772445 0.00518707 0.00536713 0.00695494
# ...

# %%
# # a simple list
# list = ['g', 'e', 'e', 'k', 's']

# # create series form a list
# ser = pd.Series(list)
# print(ser[0])

# %%
# Generate mapping between titles and index
indices = pd.Series(metadata.index, index=metadata['tweet']).drop_duplicates()
print(indices)
# print(type(indices))
#print(indices[0])
print(corpus)
print(indices[corpus[0]])
# Out:
# tweet
# good night im #stressed xx                                                                                                                                                                                                                                                                    0
# I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw                                                                                                                                              1
# This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone                                          2
# ...

# %%
def getTweetDict(tweetList):
    myDict=dict()
    for i in range(0,len(tweetList)):
        myDict.update({i:tweetList[i]})
        #print(myDict)
    return myDict

# %%
twitDict=getTweetDict(corpus)
print(twitDict)
# Out:
# {0: 'good night im #stressed xx', 1: 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', 2: "This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone", 3: 'Home alone and I can’t find my 🌹! #Stressed 😂😂😂', 4: "🚨Hoping for a good day. I've got so much that needs to get done but can't do it without some help. My life is mostly unbearable and I need help. Please help me. Goal200\n\n#help #stressed #hope #Donation\n\nhttps://t.co/l9nqZldVpl\nVenmo: Dennis-M-3 \nPaypal:dennishrh88@gmail.com", 5: '"I was under pressure" is not an excuse for toxic #behavior. \n\nBeing #stressed doesn\'t justify #hostility.\nIt\'s not your #Responsibility to absorb their pain. \n\nBeing busy doesn\'t license incivility.\nNo one\'
# ...

# %%
def get_key(val,my_dict):
    for key, value in my_dict.items():
         if val == value:
             return key
 
    return "key doesn't exist"

# %%
def uniques(duplicates):
    seen = set()
    return [seen.add(elem) or elem for elem in duplicates if elem not in seen]

# %% [markdown]
# It takes 0.012354612350463867 seconds seconds using linear_kernel while it takes  0.02692437171936035 seconds using cosine_similarity

# %%
def get_recommendations(title, cosine_sim, indices):
    # Get the index of the tweet that matches the title
    #idx = indices[title]
    idx=get_key(title,twitDict)
    #print(idx,">>>>>\n")
    # Get the pairwsie similarity scores
    #print(cosine_sim[idx],"\n...................................................................................................\n")
    sim_scores = list(enumerate(cosine_sim[idx]))
    #print(sim_scores)
    # Sort the tweet based on the similarity scores
    sim_scores = sorted(sim_scores,key=lambda x:x[1],reverse=True)
    #print(sim_scores)
#     sim_scores=uniques(sim_scores)
#     print(sim_scores)
    # Get the scores for 10 most similar tweet
    newList=list()
#     for j in range(0,10):
#         for k in range(0,10):
#             if(newList[k][1]==newList[j][1]):
                
                
#     for t in sim_scores:
#         print(t)
#         if t[1] not in newList:
#             newList.append(t[1])
#     #print("New List now: \n",newList)
#     sim_scores=list(enumerate(newList))
    #print(len(sim_scores))
    sim_scores = sim_scores[1:11]
    #print(sim_scores)
    # Get the tweet indices
    tweet_indices = [i[0] for i in sim_scores]
    #print(tweet_indices)
    # Return the top 10 most similar tweets
    return metadata['tweet'].iloc[tweet_indices]

# %%
print(cosine_sim)
print(corpus[18])
# Out:
# [[1.         0.00853824 0.00610679 ... 0.0082206  0.00695311 0.00695311]
#  [0.00853824 1.         0.04228203 ... 0.00498269 0.00421444 0.00421444]
#  [0.00610679 0.04228203 1.         ... 0.09285393 0.00301428 0.00301428]
#  ...
#  [0.0082206  0.00498269 0.09285393 ... 1.         0.00405765 0.00405765]
#  [0.00695311 0.00421444 0.00301428 ... 0.00405765 1.         1.        ]
#  [0.00695311 0.00421444 0.00301428 ... 0.00405765 1.         1.        ]]
# good night im #stressed xx

# %%
for text in corpus:
    print(text,":\n")
    print(get_recommendations(text,cosine_sim, indices))
    print("*******************************************************************************************\n\n")
# Out:
# good night im #stressed xx :
#
# 130
# [(18, 1.0), (6, 0.1897841014748295), (24, 0.1897841014748295), (8, 0.12070450094965986), (26, 0.12070450094965986), (84, 0.09045654286504637), (95, 0.09045654286504637), (4, 0.07981698270417528), (22, 0.07981698270417528), (3, 0.031776281536052164)]
# [18, 6, 24, 8, 26, 84, 95, 4, 22, 3]
# 18                           good night im #stressed xx
# 6     getting my results td but idk at what time so ...
# 24    getting my results td but idk at what time so ...
# 8     This weekend @nirne had a nightmare of being i...
# 26    This weekend @nirne had a nightmare of being i...
# 84    Count to ten I need to count to 100 🙄🙄🙄The cha...
# 95    Count to ten I need to count to 100 🙄🙄🙄The cha...
# 4     🚨Hoping for a good day. I've got so much that ...
# 22    🚨Hoping for a good day. I've got so much that ...
# 3       Home alone and I can’t find my 🌹! #Stressed 😂😂😂
# Name: tweet, dtype: object
# ...

# %%
# print(twitDict)
# print(type(twitDict))
print(get_key(125,twitDict))
# Out:
# key doesn't exist

# %%
#Returning the list of tweets with thier replies after similarity computation
def get_grouped_tweet_with_replies_after_similarity_calculation(tweetDict,similarTweets_dict):
#     returnedGroupList=[]
    similarTweets_dict_copy=similarTweets_dict
    for tweet in tweetDict:
        for key,value in similarTweets_dict.items():
#             print("value: ",value)
#             print("tweet text: ",tweet.get('text'))
            if tweet.get('text')==value:
                #print("found...: ",tweet)
                value=tweet
                similarTweets_dict[key]=value
#                 print("Value now: >>>",value)
#                 print("similarTweets_dict now: <<<<>>>>>>",similarTweets_dict)
    return similarTweets_dict_copy,similarTweets_dict

# %%
#returning the dictionary from the json file
def getDict_from_json(jsonFile):
    returned_dict=list()
    with open(jsonFile) as fileHandler:
        returned_dict=json.load(fileHandler)
    return returned_dict

# %%
returned_dict=getDict_from_json('data/my_analyzed_data_25_06.json')
#print(returned_dict)
similarTweets_dict_list=list(dict())
for text in corpus:
    similarTweets_dict=get_recommendations(text,cosine_sim, indices)
    similarTweets_dict_copy,similarTweets_dict=get_grouped_tweet_with_replies_after_similarity_calculation(returned_dict,similarTweets_dict)
    #print(similarTweets_dict_copy,'\n___________________________________\n')
    #print("reformed: ",similarTweets_dict)
    tweet_with_group_dict={"tweet text":text,"tweet group":similarTweets_dict}
    similarTweets_dict_list.append(tweet_with_group_dict)
print("all list of tweets : \n",similarTweets_dict_list)
# Out:
# all list of tweets :
#  [{'tweet text': 'good night im #stressed xx', 'tweet group': 18    {'created_at': '2022-06-13 22:56:56+00:00', 'i...
# 6     {'created_at': '2022-06-13 09:28:48+00:00', 'i...
# 24    {'created_at': '2022-06-13 09:28:48+00:00', 'i...
# 8     {'created_at': '2022-06-13 06:06:58+00:00', 'i...
# 26    {'created_at': '2022-06-13 06:06:58+00:00', 'i...
# 84    {'created_at': '2022-06-21 17:35:06+00:00', 'i...
# 95    {'created_at': '2022-06-21 17:35:06+00:00', 'i...
# 4     {'created_at': '2022-06-13 14:21:47+00:00', 'i...
# 22    {'created_at': '2022-06-13 14:21:47+00:00', 'i...
# 3     {'created_at': '2022-06-13 15:17:14+00:00', 'i...
# Name: tweet, dtype: object}, {'tweet text': 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', 'tweet group': 19     {'created_at': '2022-06-13 18:47:52+00:00', 'i...
# 4      {'created_at': '2022-06-13 14:21:47+00:00', 'i...
# ...

# %%
import requests
import json
# corpus=[corpus[i] for i in range(len(corpus)-1)]
print(len(corpus))
myList=list()
for tex in corpus:
    myList.append(tex)

print(type(myList))
print(type(corpus))
payload = json.dumps(myList)
headers = {
  'Content-Type': 'application/json'
}

for text in myList:
  
    url = "http://localhost:85/create_recommendation?sentence="+text
    print(text)
    response = requests.request("POST", url, headers=headers, data=payload)

    print(response.text)
# Out:
# 125
# <class 'list'>
# <class 'list'>
# good night im #stressed xx
# {"18":"good night im #stressed xx","6":"getting my results td but idk at what time so im gonna be #stressed all day😔","24":"getting my results td but idk at what time so im gonna be #stressed all day😔","8":"This weekend @nirne had a nightmare of being in a plane crash. So what does she do?\n\nShe has spent Sunday night watching an Amelia erhardt and Sully documentary #stressed https://t.co/EHRLHVvXah"}
# I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋
#
# #nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw
# ...

# %%
for i in range(len(myList)):
    if myList[i]==myList[i+1]

# %%
# print(corpus)
# for text in corpus:
#     print(text)
# Out:
# ['good night im #stressed xx', 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', "This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone", 'Home alone and I can’t find my 🌹! #Stressed 😂😂😂', "🚨Hoping for a good day. I've got so much that needs to get done but can't do it without some help. My life is mostly unbearable and I need help. Please help me. Goal200\n\n#help #stressed #hope #Donation\n\nhttps://t.co/l9nqZldVpl\nVenmo: Dennis-M-3 \nPaypal:dennishrh88@gmail.com", '"I was under pressure" is not an excuse for toxic #behavior. \n\nBeing #stressed doesn\'t justify #hostility.\nIt\'s not your #Responsibility to absorb their pain. \n\nBeing busy doesn\'t license incivility.\nNo one\'s calendar is too 
# ...
