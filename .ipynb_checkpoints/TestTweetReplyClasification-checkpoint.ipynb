# %%
import csv
# import the pandas library
import json
#import pandas as pd

# %%
# tweetRepliesData=pd.read_csv('TweetExtraction\cleaned_tweet_with_replies_only.csv')
tweetList=list()
with open("data\cleaned_tweet_with_replies_only.json",encoding="UTF-8") as tweetData:
    print(tweetData)
    tweetList=json.load(tweetData)
print(tweetList)
# Out:
# <_io.TextIOWrapper name='data\\cleaned_tweet_with_replies_only.json' mode='r' encoding='UTF-8'>
# [{'created_at': '2022-06-13 22:56:56+00:00', 'id': '1536482781139705857', 'text': 'good night im #stressed xx', 'source': 'Twitter for iPhone', 'name': '\u200eً ★ mar’s fiancé ?! 2', 'username': 'tobesocharly', 'location': 'my policeman enthusiast     ⌗1 Nana’s House stan !!\n   💿 TRACK 1 & 11 OWNER ¿??\nzZz married to kiwi intro          … home = louist91', 'verified': False, 'description': '⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRPSDk1z 🚬 She They', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1533745277898727427/V_3Zh2Lw_normal.jpg', 'retweets': 0, 'likes': 0, 'attachments': '[]', 'replies': '{"data":[{"id":"1536487441468727297","text":"@tobesocharly goodnightt"},{"id":"1536484151418830849","text":"@tobesocharly goodnight, sleep well and see you in a few hours&lt;3"},{"id":"1536483010605989888","text":"@sweetdayIight cries yes i will &lt;33"},{"id":"1536482927286095878","text":"@sweetdayIight i love you too sleep well mwahh"},{"id":"1536482868435771396","text":"@tobesocharly if u need to talk about it text me &lt;3"},{"id":"1536482833442775042","text":"@tobesocharly goodnight i love you"}],"meta":{"newest_id":"1536487441468727297","oldest_id":"1536482833442775042","result_count":6}}'}, {'created_at': '2022-06-13 18:47:52+00:00', 'id': '1536420101230141446', 'text': 'I have another flight tomorrow.. would you help me relieve some stress? 💋💋💋\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwtﾟ https://t.co/aJqbT98oFw', 'source': 'Twitter for Android', 'name': '\u200eً ★ mar’s fiancé ?! 2', 'username': 'tobesocharly', 'location': 'my policeman enthusiast     ⌗1 Nana’s House stan !!\n   💿 TRACK 1 & 11 OWNER ¿??\nzZz married to kiwi intro          … home = louist91', 'verified': False, 'description': '⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRPSDk1z 🚬 She They', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1533745277898727427/V_3Zh2Lw_normal.jpg', 'retweets': 0, 'likes': 9, 'attachments': "['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro.jpg - 1024x803 - Alt: None', 'https://pbs.twimg.com/media/FVJ18DWWUAI77o8.jpg - 1024x919 - Alt: None']", 'replies': '{"data":[{"id":"1536483956304093185","text":"@ChomperKat Sure. Just tell me what I can do \\uD83D\\uDE0C"},{"id":"1536420468424691712","text":"@ChomperKat Sure! :)"}],"meta":{"newest_id":"1536483956304093185","oldest_id":"1536420468424691712","result_count":2}}'}, {'created_at': '2022-06-13 15:33:42+00:00', 'id': '1536371239723360257', 'text': "This life has really beaten me down and now I'm hopeful it's going to change but I need your help. \n\nLife isn't supposed to be nothing but pain and suffering, but for a long time that's almost all I've had. \n\n#life #anxiety #stressed #alone", 'source': 'Twitter for Android', 'name': '\u200eً ★ mar’s fiancé ?! 2', 'username': 'tobesocharly', 'location': 'my policeman enthusiast     ⌗1 Nana’s House stan !!\n   💿 TRACK 1 & 11 OWNER ¿??\nzZz married to kiwi intro          … home = louist91', 'verified': False, 'description': '⠀⠀ ⠀ ⠀. . . vic de angelis’ https://t.co/0jVRPSDk1z 🚬 She They', 'profile_image_url': 'https://pbs.twimg.com/profile_images/1533745277898727427/V_3Zh2Lw_normal.jpg', 'retweets': 0, 'likes': 3, 'attachments': '[]', 'replies': '{"data":[{"id":"1536407609988849672","text":"@WorkerUnityNow You are so welcome! Literally!  :)"},{"id":"1536394809925111808","text":"@myfiVeApp Thank you ❤️"},{"id":"1536383454543335424","text":"@WorkerUnityNow You\'re not alone! We don\'t want you to feel that way. We made an app that allows you to find the top 5 people most like you wherever you go and we\'d love for you to join our community!\\n\\nDM with any Q\'s!\\n\\nIOS:  https://t.co/DM2bXJh0DV\\n\\nAndroid: https://t.co/86MylpD88F"}],"meta":{"newest_id":"1536407609988849672","oldest_id":"1536383454543335424","result_count":3}}'}, {'created_at': '2022-06-13 15:17:14+00:00', 'id': '1536367096954621954', 'text': 'Home alone and I can’t find my 🌹! #Stressed 😂😂😂', 'source': 'Twitter for iPhone', 'name': '\u200eً ★ ma ...

# %%
#Return list of tweet replies
def render_reply_list(tweet):
    replies=tweet['replies']
    # data=replies['data']
    res = json.loads(replies)
    # print(type(res))
    # print(res['data'])
    return res['data']

# %%
import requests
#map each tweet replies with its corresponding classification
def classify_tweet_replies(replies):
    reply_with_sentiment_analyzis_list=list()
    
    for reply in replies:
        url = "http://localhost/predict-review?review="+reply['text']

        payload = ""
        headers = {}

        response = requests.request("GET", url, headers=headers, data=payload)
        reply_with_sentiment_dict={"reply":reply['text'],"classification":response.text}
        reply_with_sentiment_analyzis_list.append(reply_with_sentiment_dict)
        
    #     print(reply['text'])
    #     print(response.text) print("*"*50)
    
    # print(reply_with_sentiment_analyzis_list)
    # print("*"*50)
    return reply_with_sentiment_analyzis_list

# %%
print(type(tweetList))
print(type(tweetList[1]['replies']))
# Out:
# <class 'list'>
# <class 'str'>

# %%
print(type(render_reply_list(tweetList[1])))
# Out:
# <class 'list'>

# %%
new_tweet_dictionary_list=list(dict())
for tweet in tweetList:
    
   classification=classify_tweet_replies(render_reply_list(tweet))
   new_tweet_dictionary_list.append({"tweet":tweet['text'],"attachement":tweet['attachments'],"analysis":classification})
# print(new_tweet_dictionary_list)
# json.dump(new_tweet_dictionary_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 new_tweet_dictionary_list=list(dict())
#       2 for tweet in tweetList:
# ----> 4    classification=classify_tweet_replies(render_reply_list(tweet))
#       5    new_tweet_dictionary_list.append({"tweet":tweet['text'],"attachement":tweet['attachments'],"analysis":classification})
#
# NameError: name 'classify_tweet_replies' is not defined

# %%
# convert into json
final_data = json.dumps(new_tweet_dictionary_list, indent=2)
print(final_data)
# Out:
# [
#   {
#     "tweet": "good night im #stressed xx",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@tobesocharly goodnightt",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@tobesocharly goodnight, sleep well and see you in a few hours&lt;3",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0
- Alt: None']",
#     "analysis": [
#       {
#         "reply": "@ChelBowPhill @notonthehighst @suzieleeknits Hello Chel, thank you for getting in touch. I am sorry to hear that you have yet to receive your order. Please send us a direct message or email us at info@notonthehighstreet.com stating your order number and we can look into this further for you. Best wishes, Fiona",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Viewing A Romantic Partner\u2019s Picture Reduces Stress.\n\n#psychologyfact #stressed #mindsjournal #themindsjournal https://t.co/cUyhLRDxfM",
#     "attachement": "['https://pbs.twimg.com/media/FU4iCPuUsAAjaL2.png - 700x700 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@AnikaTHoque @TheMindsJournal But SRK is not her romantic partner. He is gauri khan's.",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.28\"}"
#       },
#       {
#         "reply": "@TheMindsJournal @iFarinablog_30",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@TheMindsJournal Is this how you feel about Shahrukh Khan?",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.17\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Healing Music with Beautiful Landscapes - 528 Hz Music https://t.co/zT8pXuHkvq #calm #relaxing #meditation #CALM #relaxation #sleep #Vegan #nature  #NaturePhotography #yoga #InSomnia #stress #stressrelief #stressed https://t.co/oZmKdAd255",
#     "attachement": "['None - 2160x2160 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@TreeOfLife_Vid Instant follow back\n\ud83d\udc49 @21Mayking \ud83d\udcaf",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.31\"}"
#       },
#       {
#         "reply": "@TreeOfLife_Vid @navsurani",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@TreeOfLife_Vid @JaphetZuma",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Trying to figure out where to travel to and when, considering I have to change an Easyjet flight I have booked.\nAny suggestions? Unfortunately Easyjet only flies to a few places from Madrid, so I am between London (Gatwick), Liverpool or Edinburgh again. #stressed #onlyhave2weeks",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@lismichelle Well... I feel like I need to go to Madrid so I can join you on any trip! :) lol I love London, it's always fun to visit! I haven't been to the other 2 :( but want to visit them soooo bad!!!",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Former #Brazilian #President #stressed that the #Palestinian #people have the #right to #live in a \"#free and #sovereign #state\", \n\n#Palestine \n#USOfficeofPalestinianAffairs https://t.co/Ysu3yEPowD",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "adding that he will #work to reestablish the #leading role of Brazilian #ForeignPolicy  in the #mediation of #conflicts and of #peoples' #right to #defend themselves.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.37\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "good night im #stressed xx",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@tobesocharly goodnightt",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@tobesocharly goodnight, sleep well and see you in a few hours&lt;3",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       },
#       {
#         "reply": "@sweetdayIight cries yes i will &lt;33",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.39\"}"
#       },
#       {
#         "reply": "@sweetdayIight i love you too sleep well mwahh",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.02\"}"
#       },
#       {
#         "reply": "@tobesocharly if u need to talk about it text me &lt;3",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.13\"}"
#       },
#       {
#         "reply": "@tobesocharly goodnight i love you",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.03\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "I have another flight tomorrow.. would you help me relieve some stress? \ud83d\udc8b\ud83d\udc8b\ud83d\udc8b\n\n#nsfwtwt #nsfw #horny #stressed #nsfwtwt\uff9f https://t.co/aJqbT98oFw",
#     "attachement": "['https://pbs.twimg.com/media/FVJ17t-WUAAu8ro.jpg - 1024x803 - Alt: None', 'https://pbs.twimg.com/media/FVJ18DWWUAI77o8.jpg - 1024x919 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@ChomperKat Sure. Just tell me what I can do \ud83d\ude0c",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.37\"}"
#       },
#       {
#         "reply": "@ChomperKat Sure! :)",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet":
- Alt: None']",
#     "analysis": [
#       {
#         "reply": "@TreeOfLife_Vid Instant follow back\n\ud83d\udc49 @21Mayking \ud83d\udcaf",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.31\"}"
#       },
#       {
#         "reply": "@TreeOfLife_Vid @navsurani",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@TreeOfLife_Vid @JaphetZuma",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Trying to figure out where to travel to and when, considering I have to change an Easyjet flight I have booked.\nAny suggestions? Unfortunately Easyjet only flies to a few places from Madrid, so I am between London (Gatwick), Liverpool or Edinburgh again. #stressed #onlyhave2weeks",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@lismichelle Well... I feel like I need to go to Madrid so I can join you on any trip! :) lol I love London, it's always fun to visit! I haven't been to the other 2 :( but want to visit them soooo bad!!!",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Former #Brazilian #President #stressed that the #Palestinian #people have the #right to #live in a \"#free and #sovereign #state\", \n\n#Palestine \n#USOfficeofPalestinianAffairs https://t.co/Ysu3yEPowD",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "adding that he will #work to reestablish the #leading role of Brazilian #ForeignPolicy  in the #mediation of #conflicts and of #peoples' #right to #defend themselves.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.37\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "#STRESSED ! Wish me luck. https://t.co/vsEpnuLlbT",
#     "attachement": "['https://pbs.twimg.com/media/FU9VF6KXwAANnPi.jpg - 2048x1146 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@MooniMondschein Thank you mooniiiii \u2665\ufe0f\ud83e\udd70",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@patpranbestbfs Thank youuu \ud83e\udd7a\ud83e\udd70",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@MrsKorapat \ud83e\udd1f\ud83c\udffc\ud83d\ude09 https://t.co/wnUDs9r2S9",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@MrsKorapat Good luck Mel u can do it and u are sooo pretty \ud83d\ude33",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "@HDFCBank_Cares @HDFC_Bank #stressed #hdfcbank #note #timewast #credit not able to use this what kind of service is this tell me how it is possible we pay card fee qe do all hut while serving us the #CustomerService \nNo proper response #emails but no response from your end https://t.co/VyeS1CXUhM",
#     "attachement": "['https://pbs.twimg.com/media/FU8LHhtaIAAGVyI.jpg - 2048x945 - Alt: None', 'https://pbs.twimg.com/media/FU8LH_-akAAu9FL.jpg - 2048x945 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@HDFCBank_Cares More then 12 hours over u have not solved the issue",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares Still the same from different browser also sane what kind of service is this i don't understand @HDFC_Bank @HDFCLIFE https://t.co/SlYSc9T4ed",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.03\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I did the same more than 5 times but same issue showing",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.21\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, we regret for any inconvenience caused. We note that insta card is not working. We request you to clear the temporary files, cookies and cache files and try again. Also, we suggest you to try in different browsers. -Varun",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I have not got any updates from your end @HDFC_Bank @HDFCLIFE @hdfcsec",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.40\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares More how much time kindly let me know",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, thank you for sharing the details. I will ensure that it is taken up promptly. -Varun",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.44\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I have Send you in DM kindly check",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo the details on Public Forum and only in the DM. -Manoj https://t.co/dQJRt1zIHU",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, we'll certainly look into this for you. Kindly DM us the Card Application No., along with the mobile number &amp; email ID for further assistance. All the details you provide will remain confidential and only be visible to HDFC Bank Admin. Also, we would request you to not post",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Relaxing Sleep Music with Rain Sounds HD&gt;&gt; https://t.co/tjRIlmKhzd #rain #CALM #relaxation #sleep #Vegan #nature  #NaturePhotography #yoga #InSomnia #stress #stressrelief #stressed #stressmanagement #forest #forests @VeganFollowers @GainWithSam #water https://t.co/PVlId7G8Np",
#     "attachement": "['None - 2160x3840 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Worst thing about losing an IG 4 me is the looooong list of potential models that i lose in the process\ud83d\ude29 #STRESSED",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@TheDestinysToes @wgtfent @Footacular1 This is why I keep screenshots &amp; use the notes app \u261d\ud83c\udffe",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.30\"}"
#       },
#       {
#         "reply": "@wgtfent @Footacular1 We got violated wayyy too many times for really dumb shit after that we just decided a Twitter it is",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.30\"}"
#       },
#       {
#         "reply": "@TheDestinysToes @Footacular1 I\u2019m never gonna put my all into IG like back in the day but i don\u2019t think i could fully dead the platform. It\u2019s just too popular \ud83d\ude29",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@Footacular1 @wgtfent Amen! We started late w twitter and lost IG THREE TIMES!",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.29\"}"
#       },
#       {
#         "reply": "@wgtfent Yea! Everyone just don\u2019t fuck wit Twitter like that. But I can\u2019t play those IG games no more \ud83e\udd26\ud83c\udffd\u200d\u2642\ufe0f",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.43\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "i am #stressed besties",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@vincentsIove WHY\u203c\ufe0f",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Studying for finals! #finals #stressed #URC @LeFortniteW https://t.co/WA4TnK22bE",
#     "attachement": "['None - 854x640 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@a_marangiello who tf is this bum",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.36\"}"
#       },
#       {
#         "reply": "@a_marangiello @LeFortniteW Look at my son. So proud of him!!!\ud83d\ude07",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "just another day of me wanting to quit my jobs and drop out of school and just like run a coffee shop or something #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@complaingel Wow that is truly the dream",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.15\"}"
#       },
#       {
#         "reply": "@jilly_bby We can open one together if you want cuz I\u2019m right there with you",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@jilly_bby i want to own and operate the bar from its always sunny with my closest friends but society won\u2019t accept that \ud83d\ude14",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.29\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "@ThreeUK customer service is so bad. All I want to do is turn off my voicemail because Three are the only people leaving me voicemails. 20 mins on hold so far and I got disconnected. #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@MarieMcgee66 Oh no! We're so sorry about that, Marie. That's not a great experience and we want to turn that around. Please reach out to us here: https://t.co/cpJkjb9o56. Please make sure you\u2019re the account holder. We\u2019re here 8am \u2013 8pm during the week and 9am \u2013 6pm at the weekend -Suzi",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "very #stressed feeling #stupid",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "https://t.co/2BlGnxH73J",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "I shouldn't be made to feel like shit just cos I asked u to do something \ud83d\ude15  #stressed #notfair #fucklife",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@hatreenax Its a case of having to be ok but thank you xxx",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@pooliechick Aww hope your doing ok \u2764\ufe0f\u2764\ufe0f\u2764\ufe0f",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.30\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "With your last $50 would you put it into Luna Classic or would you buy groceries?                                   #lunaClassic #lunc #luncburn #dirtpoor #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@halfwaythere_1 @1LUNCarmy If you only have 50 dollars left, I won't invest it in #LUNC .",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy I guess the question should be, would you put $50 into lunc? If the burn rate is as predicted that $50 could turn into $690,000.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.33\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy @halfwaythere_1 https://t.co/QwD35Lb15v",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@1LUNCarmy @halfwaythere_1 #Luna is a very good example. Most people who invested all their money ended up jumping off the building.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@halfwaythere_1 Never put your last money into #cryptocurrency whether it's #lunc #BTC or anything! Only put in what you can afford! \ud83e\udd19",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.22\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "#STRESSED ! Wish me luck. https://t.co/vsEpnuLlbT",
#     "attachement": "['https://pbs.twimg.com/media/FU9VF6KXwAANnPi.jpg - 2048x1146 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@MooniMondschein Thank you mooniiiii \u2665\ufe0f\ud83e\udd70",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@patpranbestbfs Thank youuu \ud83e\udd7a\ud83e\udd70",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@MrsKorapat \ud83e\udd1f\ud83c\udffc\ud83d\ude09 https://t.co/wnUDs9r2S9",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@MrsKorapat Good luck Mel u can do it and u are sooo pretty \ud83d\ude33",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "@HDFCBank_Cares @HDFC_Bank #stressed #hdfcbank #note #timewast #credit not able to use this what kind of service is this tell me how it is possible we pay card fee qe do all hut while serving us the #CustomerService \nNo proper response #emails but no response from your end https://t.co/VyeS1CXUhM",
#     "attachement": "['https://pbs.twimg.com/media/FU8LHhtaIAAGVyI.jpg - 2048x945 - Alt: None', 'https://pbs.twimg.com/media/FU8LH_-akAAu9FL.jpg - 2048x945 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@HDFCBank_Cares More then 12 hours over u have not solved the issue",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares Still the same from different browser also sane what kind of service is this i don't understand @HDFC_Bank @HDFCLIFE https://t.co/SlYSc9T4ed",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.03\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I did the same more than 5 times but same issue showing",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.21\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, we regret for any inconvenience caused. We note that insta card is not working. We request you to clear the temporary files, cookies and cache files and try again. Also, we suggest you to try in different browsers. -Varun",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I have not got any updates from your end @HDFC_Bank @HDFCLIFE @hdfcsec",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.40\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares More how much time kindly let me know",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, thank you for sharing the details. I will ensure that it is taken up promptly. -Varun",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.44\"}"
#       },
#       {
#         "reply": "@HDFCBank_Cares I have Send you in DM kindly check",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo the details on Public Forum and only in the DM. -Manoj https://t.co/dQJRt1zIHU",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@AbhiBeardoo Hi, we'll certainly look into this for you. Kindly DM us the Card Application No., along with the mobile number &amp; email ID for further assistance. All the details you provide will remain confidential and only be visible to HDFC Bank Admin. Also, we would request you to not post",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Relaxing Sleep Music with Rain Sounds HD&gt;&gt; https://t.co/tjRIlmKhzd #rain #CALM #relaxation #sleep #Vegan #nature  #NaturePhotography #yoga #InSomnia #stress #stressrelief #stressed #stressmanagement #forest #forests @VeganFollowers @GainWithSam #water https://t.co/PVlId7G8Np",
#     "attachement": "['None - 2160x3840 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34\ud83c\udf34",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Worst thing about losing an IG 4 me is the looooong list of potential models that i lose in the process\ud83d\ude29 #STRESSED",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@TheDestinysToes @wgtfent @Footacular1 This is why I keep screenshots &amp; use the notes app \u261d\ud83c\udffe",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.30\"}"
#       },
#       {
#         "reply": "@wgtfent @Footacular1 We got violated wayyy too many times for really dumb shit after that we just decided a Twitter it is",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.30\"}"
#       },
#       {
#         "reply": "@TheDestinysToes @Footacular1 I\u2019m never gonna put my all into IG like back in the day but i don\u2019t think i could fully dead the platform. It\u2019s just too popular \ud83d\ude29",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@Footacular1 @wgtfent Amen! We started late w twitter and lost IG THREE TIMES!",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.29\"}"
#       },
#       {
#         "reply": "@wgtfent Yea! Everyone just don\u2019t fuck wit Twitter like that. But I can\u2019t play those IG games no more \ud83e\udd26\ud83c\udffd\u200d\u2642\ufe0f",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.43\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "i am #stressed besties",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@vincentsIove WHY\u203c\ufe0f",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Studying for finals! #finals #stressed #URC @LeFortniteW https://t.co/WA4TnK22bE",
#     "attachement": "['None - 854x640 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@a_marangiello who tf is this bum",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.36\"}"
#       },
#       {
#         "reply": "@a_marangiello @LeFortniteW Look at my son. So proud of him!!!\ud83d\ude07",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.01\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "just another day of me wanting to quit my jobs and drop out of school and just like run a coffee shop or something #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@complaingel Wow that is truly the dream",
# ...
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@MarieMcgee66 Oh no! We're so sorry about that, Marie. That's not a great experience and we want to turn that around. Please reach out to us here: https://t.co/cpJkjb9o56. Please make sure you\u2019re the account holder. We\u2019re here 8am \u2013 8pm during the week and 9am \u2013 6pm at the weekend -Suzi",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "very #stressed feeling #stupid",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "https://t.co/2BlGnxH73J",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "I shouldn't be made to feel like shit just cos I asked u to do something \ud83d\ude15  #stressed #notfair #fucklife",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@hatreenax Its a case of having to be ok but thank you xxx",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@pooliechick Aww hope your doing ok \u2764\ufe0f\u2764\ufe0f\u2764\ufe0f",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.30\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "With your last $50 would you put it into Luna Classic or would you buy groceries?                                   #lunaClassic #lunc #luncburn #dirtpoor #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@halfwaythere_1 @1LUNCarmy If you only have 50 dollars left, I won't invest it in #LUNC .",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy I guess the question should be, would you put $50 into lunc? If the burn rate is as predicted that $50 could turn into $690,000.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.33\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy @halfwaythere_1 https://t.co/QwD35Lb15v",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       },
#       {
#         "reply": "@1LUNCarmy @halfwaythere_1 #Luna is a very good example. Most people who invested all their money ended up jumping off the building.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@halfwaythere_1 Never put your last money into #cryptocurrency whether it's #lunc #BTC or anything! Only put in what you can afford! \ud83e\udd19",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.22\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "very #stressed feeling #stupid",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "https://t.co/2BlGnxH73J",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.18\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "I shouldn't be made to feel like shit just cos I asked u to do something \ud83d\ude15  #stressed #notfair #fucklife",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@hatreenax Its a case of having to be ok but thank you xxx",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@pooliechick Aww hope your doing ok \u2764\ufe0f\u2764\ufe0f\u2764\ufe0f",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.30\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "With your last $50 would you put it into Luna Classic or would you buy groceries?                                   #lunaClassic #lunc #luncburn #dirtpoor #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@halfwaythere_1 @1LUNCarmy If you only have 50 dollars left, I won't invest it in #LUNC .",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy I guess the question should be, would you put $50 into lunc? If the burn rate is as predicted that $50 could turn into $690,000.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.33\"}"
#       },
#       {
#         "reply": "@bwww77 @1LUNCarmy @halfwaythere_1 https://t.co/QwD35Lb15v",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0

#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.37\"}"
#       },
#       {
#         "reply": "@cjlow_ @Mattytargett It doesn\u2019t take so long for the media side to be done and never has. It\u2019s not held up by media related duties. Our department and everyone in it have always been professional and we are not doing anything we never already did before. Just saying. \ud83d\ude0a",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@iamserenataylor @Mattytargett You have just photo shopped Targett over Dan Ashworth \ud83d\ude2d\ud83d\ude2d\ud83d\ude02",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.13\"}"
#       },
#       {
#         "reply": "@iamserenataylor @MitchT1998 @Mattytargett Great work Serena ...keep it up plenty more to do this summer I reckon",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.15\"}"
#       },
#       {
#         "reply": "@iamserenataylor @Mattytargett Loving your work! Great gig?",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.37\"}"
#       },
#       {
#         "reply": "@iamserenataylor @Mattytargett I love MT because he's so understated - exactly the type of personality that we should be bringing to the club as we move into phase two of the project.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@manxpie86 @iamserenataylor @Mattytargett Twats dressed like twas and Matt Targett",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.32\"}"
#       },
#       {
#         "reply": "@iamserenataylor @Mattytargett well done :)",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@iamserenataylor @Mattytargett #NUFC https://t.co/oPimcb48aG",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Getting ready for thin vendor event just reminded me why i don\u2019t do them #stressed",
#     "attachement": "[]",
#     "analysis": [
#       {
#         "reply": "@STLStylings Next week",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.34\"}"
#       },
#       {
#         "reply": "@AQualityMess I just saw your TikTok! When is yours? Mines is Saturday",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.32\"}"
#       },
#       {
#         "reply": "@STLStylings Whew girl same",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.32\"}"
#       }
#     ]
#   },
#   {
#     "tweet": "Look at that, a year ago today since I paid my deposit on my @AsterGroupUK home &amp; I\u2019ve still got no move date \ud83d\ude33 #delayedhousemove #Stressed #livinginlimbo #unsettled #fedup #justwanttomove https://t.co/XnKshioKEp",
#     "attachement": "['https://pbs.twimg.com/media/FUvCu7MWIAITPNa.jpg - 383x750 - Alt: None']",
#     "analysis": [
#       {
#         "reply": "@N1181xX Yep, the excitement has been replaced with anxiety &amp; feeling frightened that we\u2019ll be homeless! We are in a similar situation where the house is there, we have been inside it &amp; looked round, yet it still won\u2019t get signed off \ud83d\ude33 It\u2019s so disheartening \ud83e\udd7a",
#         "classification": "{\"prediction\":\"Neutral\",\"Probability\":\"0.21\"}"
#       },
#       {
#         "reply": "@jenstimp That\u2019s nearly a year!! So sorry to hear this, it must have ruined any excitement completely for you all. Site we were looking at is in Farnham. From what I can see all the houses are ready but the road doesn\u2019t seem to be finished",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.00\"}"
#       },
#       {
#         "reply": "@N1181xX Where abouts are you looking? They\u2019ve said that the delays are lack of builders &amp; materials, which is ridiculous as they have continued to build other houses on the site! I was meant to move August 2021 &amp; am still waiting, with no move date in sight!",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       },
#       {
#         "reply": "@jenstimp Someone else in the same boat as you on trustpilot plus others. Have they told you what the delay is? Phase 1 of where I\u2019m looking was sold out January or before I think, but nobody has moved in yet and the phase 2 launch has been pushed back. Houses are all complete too.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.02\"}"
#       },
#       {
#         "reply": "@N1181xX What did you see on Trustpilot? I\u2019m just exhausted from it all &amp; communication is shockingly bad! They tried to offer me \u00a3500 in compensation, which doesn\u2019t go anywhere near the cost to cover a months rent ffs!!! If I had any choice, I\u2019d go elsewhere!",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.23\"}"
#       },
#       {
#         "reply": "@jenstimp Oh my gosh! So sorry to hear all that, shocking! I really hope you and the kids get something sorted either way. I read some reviews on trustpilot which concerned me now this.",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.24\"}"
#       },
#       {
#         "reply": "@N1181xX This is in Basingstoke! Just had the terrible news that Premier (the warranty company) have walked away, so no warranty sign off! I\u2019m almost out of money for my temporary rental, that I was meant to be in for 2 months, now over 6! My kids &amp; I are almost homeless now!",
#         "classification": "{\"prediction\":\"Negative\",\"Probability\":\"0.02\"}"
#       },
#       {
#         "reply": "@jenstimp Oh no, we\u2019ve been looking at an Aster home. Which development is this if you don\u2019t mind me asking?",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.26\"}"
#       },
#       {
#         "reply": "@AsterGroupUK I\u2019m in talks with team members &amp; now on level 2 of my complaints! People need to know how long they could be delayed, so they don\u2019t end up severely out of pocket, almost homeless, stressed beyond belief &amp; living in limbo for a year or more!",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.41\"}"
#       },
#       {
#         "reply": "@jenstimp Hi Jen - sorry to hear this.  We understand our sales team are in communication about this but please drop us a DM if you\u2019d like a member of the sales team to contact you.",
#         "classification": "{\"prediction\":\"Positive\",\"Probability\":\"0.27\"}"
#       }
#     ]
#   }
# ]

# %%
# convert into json
# file name is mydata
print(type(final_data))
with open("data/my_analyzed_data.json", "w") as jsonFile:
   json.dump(new_tweet_dictionary_list,jsonFile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 # convert into json
#       2 # file name is mydata
# ----> 3 print(type(final_data))
#       4 with open("data/my_analyzed_data.json", "w") as jsonFile:
#       5    json.dump(new_tweet_dictionary_list,jsonFile)
#
# NameError: name 'final_data' is not defined

# %%
#data visualization for distribution
def mapReplyWithItsClass(tweetList):
    repliesWithClassList=list()
    for tweet in tweetList:
        
        analysis=tweet['analysis']
        for each_reply_analyzis in analysis:
            reply=each_reply_analyzis['reply']
            reply_class=each_reply_analyzis['classification']
            #print(type(reply_class))
            reply_class = json.loads(reply_class)
           # print(reply_class['prediction'])
            reply_with_class_dict={"reply":reply,"group":reply_class['prediction']}
            repliesWithClassList.append(reply_with_class_dict)
            
    return repliesWithClassList

# %%
repliesWithClassList=mapReplyWithItsClass(new_tweet_dictionary_list)

# %%
with open("data/tweet_replies_distribution.json", "w") as jsonFile:
   json.dump(repliesWithClassList,jsonFile)

# %%
# warnings.filterwarnings("ignore")
# # seeding
# np.random.seed(123)
import pandas as pd
data = pd.read_csv('data/tweet_replies_distribution.csv')
categories = ['Positive','Neutral','Negative']
# data.head()
# len(data)
data.isnull().any().any()
data.isnull().any()
data = data.dropna(subset=['reply','group'])
# data['clean_text','category'].isnull().sum()
# data.isnull().any().any()
# data.isnull().any()
data.isnull().any()

# %%
def visualize():
    category_count = data.groupby('group').count()
    plt.bar(category_count.index.values, category_count["reply"])
    plt.xticks(rotation='vertical')
    plt.xlabel('Sentiment Categories')
    plt.ylabel('Number of replies')
    plt.show()
    return category_count
visualize()

# %%
print(mapReplyWithItsClass(new_tweet_dictionary_list))
